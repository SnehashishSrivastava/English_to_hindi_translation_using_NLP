# %%
import os
import pandas as pd
data_path="Hindi_English_Truncated_Corpus.csv"

# %%
dataset=pd.read_csv(data_path)
dataset.describe()
dataset.head()
# Out:
#       source                                   english_sentence  \
# 0        ted  politicians do not have permission to do what ...
# 1        ted         I'd like to tell you about one such child,
# 2  indic2012  This percentage is even greater than the perce...
# 3        ted  what we really mean is that they're bad at not...
# 4  indic2012  .The ending portion of these Vedas is called U...
#
#                                       hindi_sentence
# 0  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।

# %%
def clean_text(text):
    import re
    text=re.sub(r'(\d+)',r'',text)
    text=text.replace(u',','')
    text=text.replace(u'"','')
    text=text.replace(u'(','')
    text=text.replace(u')','')
    text=text.replace(u'"','')

    text=text.replace(u':','')
    text=text.replace(u"'",'')
    text=text.replace(u"‘‘",'')
    text=text.replace(u"’’",'')
    text=text.replace(u"''",'')
    text=text.replace(u".",'')
    return text

# %%
clean_text("राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर")
# Out:
# 'राजनीतिज्ञों के पास जो कार्य करना चाहिए वह कर'

# %%
y=[]
for hindi_sent in dataset['hindi_sentence']:
    y.append(clean_text(hindi_sent))
dataset['new']=y

# %%
dataset['new']=dataset['new'].apply(lambda x:"START_"+ x +"_END")

# %%
dataset['new'][0]
# Out:
# 'START_राजनीतिज्ञों के पास जो कार्य करना चाहिए वह करने कि अनुमति नहीं है _END'

# %%
y2
# Out:
# [(<function __main__.<lambda>(x)>,
#   'राजनीतिज्ञों के पास जो कार्य करना चाहिए वह करने कि अनुमति नहीं है '),
#  (<function __main__.<lambda>(x)>,
#   'मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी'),
#  (<function __main__.<lambda>(x)>,
#   'यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।'),
#  (<function __main__.<lambda>(x)>,
#   'हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते'),
#  (<function __main__.<lambda>(x)>,
#   'इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।'),
#  (<function __main__.<lambda>(x)>,
#   'कश्मीर के तत्कालीन गवर्नर ने इस हस्तांतरण का विरोध किया था  लेकिन अंग्रेजों की सहायता से उनकी आवाज दबा दी गयी '),
#  (<function __main__.<lambda>(x)>,
#   'इसमें तुमसे पूर्व गुज़रे हुए लोगों के हालात हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'और हम होते कौन हैं यह कहने भी वाले कि वे गलत हैं'),
#  (<function __main__.<lambda>(x)>,
#   'ग्लोबल वॉर्मिंग से आशय हाल ही के दशकों में हुई वार्मिंग और इसके निरंतर बने रहने के अनुमान और इसके अप्रत्यक्ष रूप से मानव पर पड़ने वाले प्रभाव से है।'),
#  (<function __main__.<lambda>(x)>,
#   'हो सकता है कि आप चाहते हों कि आप का नऋर्नमेनटेन्ड ह्यबिना किसी समर्थन के हृ विशेष स्कूल  या किसी स्वतंत्र स्कूल में जाए  इजसके पास विशेष शैक्षणिक जऋऋरतों वाले बच्चों के प्रति सहूलियत हों  '),
#  (<function __main__.<lambda>(x)>,
#   'कृपया यह सुनिश्चित कर लें कि आप सही फॉर्म का प्रयोग कर रहें हैं '),
#  (<function __main__.<lambda>(x)>, 'श्रेणीधर्मग्रन्थ'),
#  (<function __main__.<lambda>(x)>,
#   'यह काल समग्रतः भक्ति भावना से ओतप्रोत काल है।'),
#  (<function __main__.<lambda>(x)>, 'तो वहाँ न्याय है'),
#  (<function __main__.<lambda>(x)>,
#   'पहले दो को अविश्वसनीय मानकर बाकी पांच मुखबिरों के आधार पर मुकदमा चलाया गया '),
#  (<function __main__.<lambda>(x)>,
#   'कम संख़्या वाले उच्च एवं मध्यम श्रेणी के लोगों तक ही अपनी शिक्षा नीति को केंद्रित करने को इस तर्क के साथ न्यायसंगत बताया कि नयी शिक्षा Zक्रमश  ऊपर से नीचे की ओर छनते हुए जायेगी '),
#  (<function __main__.<lambda>(x)>,
#   'हाल में नेपाल के हस्पताल सामन्यतया आयुर्वेद प्राकृतिक चिकित्सा तथा आधुनिक चिकीत्सा करके सरकारी सेवा विद्यमान हे ।'),
#  (<function __main__.<lambda>(x)>,
#   'लोकसभा की कार्यावधि  वर्ष है पर्ंतु इसे समय से पूर्व भंग किया जा सकता है'),
#  (<function __main__.<lambda>(x)>,
#   'रजिस्टर न्यायालय जिन्हें न्यायाधीश द्वारा प्राधिकृत किए जाने पर  रु  तक के वादों का निर्णय करने का अधिकार था '),
#  (<function __main__.<lambda>(x)>,
#   'बढ़ती हुई मौतों displacements और आर्थिक नुकसान जो की अतिवादी मौसम extreme weatherके कारण संभावित हैं बढती हुई जनसँख्या growing populationके कारण और भी बदतर हो सकते हैं  हालांकि शीतोष्ण क्षेत्र में इसके कुछ फैदे भी हो सकते हैं जैसे की ठंड की वजह से कम मौतें होना '),
#  (<function __main__.<lambda>(x)>, ' लाडड़ी लोकप्रिय स्त्री नृत्य है '),
#  (<function __main__.<lambda>(x)>,
#   'यहां तक कि पानी में हाइड्रोजन सल्फाइड की  पी पी एम मात्रा से भी सड़े हुए अंडे की बदबू आती है '),
#  (<function __main__.<lambda>(x)>,
#   'इस्लाम धर्म الإسلام ईसाई धर्म के बाद अनुयाइयों के आधार पर दुनिया का दूसरा सब से बड़ा धर्म है।'),
#  (<function __main__.<lambda>(x)>, 'धीरे धीरे ये सब बदला'),
#  (<function __main__.<lambda>(x)>,
#   'एक ही जीन के उत्परिवर्तन के कारण होने वाले आनुवंशिक रोग इन सभी रोगों से अधिक महत्वपूर्ण हैंमेंडेल के सरल वितरण के नियम के अनुसार यह जीन संतानों में प्रकट होता है '),
#  (<function __main__.<lambda>(x)>,
#   'बाद में वित्तैइय संस्थाएं इन शेयरों को सुजुकी  फिलहाल  प्रतिशत शेयरधारक  और आम जनता को बेच देंगी '),
#  (<function __main__.<lambda>(x)>, 'उत्पन्न नहीं कि जाती थी'),
#  (<function __main__.<lambda>(x)>,
#   'नरेंद्र ने कौंसिल से तीन या चार मुलाकातें की किंतु उन्होनें महसूस किया कि वे किसी भी प्रकार से बात आगे नही बढ़ा पा रहे है '),
#  (<function __main__.<lambda>(x)>,
#   'जो भी इस झंडे के नीचे खड़ा है वह न हिंदू है  न मुसलमान  बल्कि वह हिंदुस्तानी है '),
#  (<function __main__.<lambda>(x)>,
#   'कुछ मामलों में प्रथम स्तर के न्यायालय होने के कारण उच्च न्यायालयों को उच्चतम न्यायालय की अपेक्षा मामलों पर अधिक कारगर ढंग से कार्रवाई करने की अधिकारिता है '),
#  (<function __main__.<lambda>(x)>, 'और जैसा आप देख रहे है ये एलईडी जल उठेगी।'),
#  (<function __main__.<lambda>(x)>,
#   'अधिनियम के अधीन एक से अधिक दावा अधिकरण स्थापित किए जा सकते हैं और उनकी अधिकारिता को अधिकरणों के गठन की अधिसूचना में विनिर्दिष्ट कर दिया जाता है '),
#  (<function __main__.<lambda>(x)>,
#   'लाईट जलाने के लिए या उनके लिए पानी लाने के लिए'),
#  (<function __main__.<lambda>(x)>, 'मेन'),
#  (<function __main__.<lambda>(x)>,
#   'फारसी रहस्यवाद में मुगल कालीन इस्लामी पाठ्य में फिरदौस को एक आदर्श पूर्णता का बाग बताया गया है।'),
#  (<function __main__.<lambda>(x)>, 'क्या आप ये कल्पना कर सकते है'),
#  (<function __main__.<lambda>(x)>,
#   'जिंदा रहने के लिए जूँ किसी जीव के सम्पर्क में रहना आवश्यक है'),
#  (<function __main__.<lambda>(x)>,
#   'तीसरी ये हमारी फ़ैक्ट्री के पास की एक अपेक्षाकृत बेहतर सडक है।'),
#  (<function __main__.<lambda>(x)>,
#   'इसमें कानूनी रोक  इंजक्शन  शामिल है जो बहुत ही प्रभावकारी रोक का उपाय है जो पैदा हुए उपद्रव को कम कर सकता है और इस बीच लोगों को अपने घरों में रहने की अनुमति भी होती है '),
#  (<function __main__.<lambda>(x)>, 'क्या हो रहा है ये?”'),
#  (<function __main__.<lambda>(x)>,
#   'मगर उनके निधन के पश्चात उनके भाई सरदार वल्लभ भाई पटेल ने इस वसीयत को स्वीकार नहीं किया और उसपर अदालत में मुकदमा चलाया।'),
#  (<function __main__.<lambda>(x)>,
#   'उन्होनें बड़े दुख के साथ यह भी देखा कि कैसे छठी कमिन्टर्न कांग्रेस की अतिवामपंथी मार्ग अपनाकर साम्यवादियों ने अपने को नष्ट कर लिया था और वामपंथी आंदोलन को भी बढ़ते देखा था '),
#  (<function __main__.<lambda>(x)>,
#   'ग्रामीण चीन में आर्थिक नवीनीकरण हुये हैं।'),
#  (<function __main__.<lambda>(x)>, 'यह इस कहानी का अंतिम सबक है '),
#  (<function __main__.<lambda>(x)>,
#   'इसमें टकरवा ही टकराव है - नए के साथ पुराने का  राज्य सत्ता बनाम आदर्शवाद का  साध्य और साधन का  अधिकार पूर्ण प्रेम और प्रेम की स्वतंत्रता का  और बाहरी जंगली हवा के साथ ग्राहस्थिक या घरेलू मूल्यों का '),
#  (<function __main__.<lambda>(x)>,
#   'अपने प्रगतिशील विचारों के कारण उन्होंने विधवा-विवाह और कन्याओं की विवाह योग्य आयु-सीमा बढ़ाने की भी वकालत की '),
#  (<function __main__.<lambda>(x)>,
#   'विश्लेषण और विवेचन बड़े गंभीर और सरस थे और शैली इतनी मोहक थी कि सारा-का-सारा लेखन साहित्य का उत्कृष्ट निदर्शन बन गया '),
#  (<function __main__.<lambda>(x)>,
#   'सन्  और  के बीच के  वर्ष अकाल के वर्ष रहे '),
#  (<function __main__.<lambda>(x)>,
#   '-झूला यह हत्थाकुर्सी से मिलती जुलती पोजीशन है इसमें पुरुष अपने पैरों को घुटनों के पास से थोड़ा उपर उठा लेता है और उसके हाथ महिला को कूल्हों के पास से सहारा देने का काम करते हैं तथा महिला अपने दोनों पैर उसकी कमर से सटाते हुए सीधे फैला लेती है तथा योनि को लिंग में प्रवेश कराने के बाद अपने हाथ उसके कंधे पर रख सहारा लेती है इसमें महिला पुरुष काफी निकट रहते हैं इससे यह काफी निकटता प्रदान करती है'),
#  (<function __main__.<lambda>(x)>,
#   'वियतनाम में परिवार योजना शुरू हो गई और उनके परिवार छोटे होने लगे।'),
#  (<function __main__.<lambda>(x)>, 'श्रेणीसूचना प्रौद्योगिकी'),
#  (<function __main__.<lambda>(x)>, 'मेरा मतलब उस समय सही मानिए'),
#  (<function __main__.<lambda>(x)>,
#   'जयेंद्र सरस्वती के लिए अध्यात्म कभी कोई स्थिर चीज नहीं रही है '),
#  (<function __main__.<lambda>(x)>, 'बस वही नहीं'),
#  (<function __main__.<lambda>(x)>,
#   'जिसे हम प्रवृत्ति कहते हैं और जिसे हम अपने दैनंदिन जीवन में बहुत तुच्छ समझ कर नकार दिया करते हैं- यही वह चीज है जो हमें सदगुणों या दुर्गुणों के अरण्य से बाहर निकालने में सहायक बनकर हमारी नियति की असीम संभावनाओं तक और हमारी चेतना एवं उल्लास तथा अनुताप तक ले जाती है '),
#  (<function __main__.<lambda>(x)>,
#   'मानवों ने उन ही साझे संसाधनों को नष्ट किया जिन पर वो आधारित थे।'),
#  (<function __main__.<lambda>(x)>,
#   'रचना करीब करीब ई तक जाती है मगर तब तो नाटक ख़त्म हो जाएगा'),
#  (<function __main__.<lambda>(x)>,
#   'आर्य देवताओं की कोई मूर्ति या मन्दिर नहीं बनाते थे।'),
#  (<function __main__.<lambda>(x)>,
#   'यह एक छोटी तीन गुम्बद वाली तराशे हुए श्वेत संगमर्मर से निर्मित है।'),
#  (<function __main__.<lambda>(x)>, 'महात्मा गांधी के साथ सरोजिनी नायडू'),
#  (<function __main__.<lambda>(x)>, 'लेकिन जनवरी   में मंदी रही '),
#  (<function __main__.<lambda>(x)>, 'बाहरी कड़ियाँ'),
#  (<function __main__.<lambda>(x)>,
#   'पिछली दीवार पर एक विशेष ताक में  एक सामान्य सोमस्कंद फल्क उकेरा गया है  जिसमें शिव और उमा बैठे हुए हैं  नन्हाँ स्कंद उमा की गोद में हैं और दोनों और ब्रह्मा और विष्णु खड़े हैं '),
#  (<function __main__.<lambda>(x)>,
#   'मैं आपके साथ कुछ मुख्य सूत्र बाँटना चाहता हूँ'),
#  (<function __main__.<lambda>(x)>,
#   'फ्रांस  बेलजियम  जर्मनी  संयुक्त राज्य अमेरिका  रूस और बाद में जापान ने अपने यहां शक्तिशाली उद्योगों का विकास किया और अपने माल की खपत के लिए विदेशी बाजार की खोज शुरू की '),
#  (<function __main__.<lambda>(x)>,
#   'पर अगर आप व्यापारी को अधिक समय देना स्वीकार करते हैं  तो आप इस समय के बीत जाने के पहले अपना आर्डर रद्द नहीं कर सकते '),
#  (<function __main__.<lambda>(x)>,
#   '[अस्पष्ट] के बहुत सारे राष्ट्रों को मान्यता चाहिए'),
#  (<function __main__.<lambda>(x)>, 'यह परिवर्तन योगदान दे रहा है'),
#  (<function __main__.<lambda>(x)>,
#   'हमने समस्या का हल निकालने का ज़िम्मा पूरे समुदाय पर डाल दिया'),
#  (<function __main__.<lambda>(x)>, 'बुद्ध और नाचघर '),
#  (<function __main__.<lambda>(x)>,
#   'अल्पकाली उद्देश्य रेखांकित करने का प्रबंध करना एवं उन उद्देश्यों के प्रति आप की नियमित उन्नति का निरीक्षण करें '),
#  (<function __main__.<lambda>(x)>,
#   'वे बहुधा उनसे मिलने की तीव्र इच्छा के बारे में भी हमें बताया करते '),
#  (<function __main__.<lambda>(x)>,
#   'इस सकारात्मक अर्थबोध में स्वतंत्रता का अर्थ होगा किसी व्यक्ति की अपनी इच्छा के अनुसार कार्य करने की स्वतंत्रता '),
#  (<function __main__.<lambda>(x)>,
#   'इस प्रकार  यद्यपि संपूर्ण ब्रिटिश इंडिया के लिए  भारत में सम्राट की ब्रिटिश प्रजा एवं सेवियों के लिए तथा ब्रिटिश इंडिया में और उससे बाहर ब्रिटिश इंडिया की सारी प्रजा के लिए केंद्रीय विधानमंडल की शक्ति को दोहराया गया परंतु उसकी अनेक महत्वपूर्ण सीमाएं बनी रहीं जो या तो ब्रिटिश संसद की प्रभुसत्ता ज्यों की त्यों बनाए रखने के लिए निर्धारित की गई थीं या Zइफर गवर्नर-जनरल तथा उसकी परिषद् की प्रभुसत्ता बनाए रखने के लिए '),
#  (<function __main__.<lambda>(x)>, 'इसके प्रभाव को बहुत ही कम आंका गया है।'),
#  (<function __main__.<lambda>(x)>,
#   'हम भिऋ स्टाऋल के थ्फ्  आवेदनपत्र का प्रयोग करते हैं जो कि इस बात पर निर्भर करता है कि आप हमें आवेदनपत्र डऋआक से या इ-मेल से भेजना चाहते हैं '),
#  (<function __main__.<lambda>(x)>,
#   'उस गुरुभाई को पाठ पढ़ाते हुए और गुरुदेव की प्रत्येक वस्तु के प्रति प्रेम दर्शाते हुए उनके बिस्तर के पास रक्त कफ आदि से भरी थूकदानी उठाकर फेकते थे।'),
#  (<function __main__.<lambda>(x)>,
#   ' संस्कृत विश्व की सबसे पुरानी पुस्तक वेद की भाषा है।'),
#  (<function __main__.<lambda>(x)>, 'कैरियर होटल'),
#  (<function __main__.<lambda>(x)>,
#   'जो वह सीखता है या पूर्व क्रमादेशित होता है|'),
#  (<function __main__.<lambda>(x)>,
#   'जहाँ भी स्कूलों में बगैर छुट्टी लिए हुए विद्यार्थियों की अनुपस्थिती जैसी समस्याएँ कम तेजी से सुधरी हैं  वहाँ सरकार अधिक कार्य कर रही है |भाष्;'),
#  (<function __main__.<lambda>(x)>,
#   'हमारी आखो के लिए अलग बनावट और अलग रंग के हैं '),
#  (<function __main__.<lambda>(x)>, 'वित्त व्यवस्था पर संसद का नियंत्रण'),
#  (<function __main__.<lambda>(x)>,
#   'किंतु इसी बीच दूसरे प्रदेशों से विशेष रूप से दक्षिण से बड़ी संख्या में लोग इन द्वीपों में आ गये  उनमें कुछ अन्य लोग विभिन्न परियोजनाओं के आधार पर यहां बसाये गए '),
#  (<function __main__.<lambda>(x)>,
#   'मुझे लगता है कोई भी बुद्धिमान जीवन इस बात को मानेगा कि'),
#  (<function __main__.<lambda>(x)>,
#   'छोटे छोटे शिशु उद्योग इस समय के मुखऋ-ऊण्श्छ्ष्-य शिशु उद्योगों में चीनी  कागज और दियासलाऋ की चर्चा की जा सकती है '),
#  (<function __main__.<lambda>(x)>,
#   'जिस दिन तुम उस झोपड़ी को दोबारा खड़ा कर पाने में समर्थ हो जाओगी  उसी दिन मैं तुम्हें रानी के रूप में स्वीकार कर पाऊंगा  ?'),
#  (<function __main__.<lambda>(x)>, ' सूरसारावली'),
#  (<function __main__.<lambda>(x)>,
#   'बागान की अपेक्षा इसमें मशीनों के अधिक उपयोग के बावजूद  कोयला खदान के काम को फैक़्ट्री प्रणाली के रूप में कम संरक्षण प्राप्त था '),
#  (<function __main__.<lambda>(x)>,
#   'हालंकि  ब्रिटेन जैसे देश के इस तरह खुलेआम कानून बनाने से कूटनीतिक तौर पर तो मदद मिलती है  लेकिन महत्वपूर्ण यह है कि इससे  मान ल कश्मीर में  बगावत पर क्या असर पड़ैगा '),
#  (<function __main__.<lambda>(x)>, 'सूखे धुंध को बनाने के लिए'),
#  (<function __main__.<lambda>(x)>,
#   'उनकी ज़िम्मेदारियों में शामिल थे स्पेसहैब/बल्ले-बल्ले/फ़्रीस्टार लघुगुरुत्व प्रयोग जिसके लिए कर्मचारी दल ने  प्रयोग किए जिनके जरिए पृथ्वी व अंतरिक्ष विज्ञान उन्नत तकनीक विकास व अंतरिक्ष यात्री स्वास्थ्य व सुरक्षा का अध्ययन हुआ।'),
#  (<function __main__.<lambda>(x)>,
#   'CO और CH की वातावरण सांद्रता atmospheric concentrations  वीं सदी के मध्य में औद्योगिक क्रांति की शुरुआत के बाद से क्रमशः % और % बढ़ गई हैपिछले  वर्षों के दौरान किसी भी समय से इन स्तरों को काफी अधिक माना जा रहा है।'),
#  (<function __main__.<lambda>(x)>,
#   'इनमें प्रमुख हैं फ़रक्का बाँध टिहरी बाँध तथा भीमगोडा बाँध।'),
#  (<function __main__.<lambda>(x)>, 'मलेरिया के मुकाबले।'),
#  (<function __main__.<lambda>(x)>,
#   'जब ये अंतरिक्ष प्रतिस्पर्धा पूरे ज़ोर पर था'),
#  (<function __main__.<lambda>(x)>,
#   'शायद कुछ ऐसी समस्याएँ हों  जिनके बारे में आप न जानते हों '),
#  (<function __main__.<lambda>(x)>,
#   'दस साल की उम्र में मुझे जबरदस्ती अखबार बेचना भेज दिया गया ।'),
#  (<function __main__.<lambda>(x)>,
#   'धार्मिक नेता इसके प्रति पूरी तरह से सजग थे तथा सभी तरह के भेद भाव को समूल उखाड़ने में सक्रिय थे '),
#  (<function __main__.<lambda>(x)>,
#   'उनका विरोध करने वालों में उस समय सबसे मुख्य दल भारतीय कम्यूनिस्ट पार्टी और अन्य वामपंथी सहयोगी दल थे।'),
#  (<function __main__.<lambda>(x)>, 'श्रेणीसंयुक्त राज्य अमेरिका'),
#  (<function __main__.<lambda>(x)>,
#   'फिर मैंने उसे Roald Dahl की “James and the Giant Peach”'),
#  (<function __main__.<lambda>(x)>,
#   'यदि जिस व्यक्ति की हत्या हुई है वह ब्राह्मण हो तो हत्यारे ब्राह्मण को अगले जन्म में उसका उत्तर देना पड़ेगा क़्योंकि उसको प्रायश्चित करने की अनुमति नहीं है इसलिए कि प्रायश्चित करने से पापी का पाप धुल जाता है जबकि नियमानुसार ब्राह्मण द्वारा किए गए किसी भी महापाप का मार्जन नहीं हो सकतामहापाप ये हैं  ब्राह्मण की हत्या जो बज्र ब्रह्म हत्या ? कहलाती है ; इसके अतिरिक़्त गो-हत्या  मद्यपान  व्यभिचार विशेष रूप से अपने पिता की और गुरू की पत्नी के साथ किया गया व्यभिचार '),
#  (<function __main__.<lambda>(x)>,
#   'हो सकता है कि कुछ बच्चे प्रत्येक शब्द बिलकुल सही पढ़ना चाहते हो जबकि अन्य कहानी के अंत तक पहुँचने की होड़ में रहेंगे '),
#  (<function __main__.<lambda>(x)>,
#   'उस समय राजसभा में भगवान् श्रीकृष्ण ने माया से अपने परम दुर्धर्ष विश्वरूप का दर्शन कराकर सबको भयभीत कर दिया।'),
#  (<function __main__.<lambda>(x)>,
#   'मांग तेजी से बढ़ रही थी और मिलों ने उपलब्ध क्षमता का उपयोग करते हुए दो पारी में काम करना शुरू कर दिया '),
#  (<function __main__.<lambda>(x)>,
#   'वीं शताब्दी के उत्तरार्ध मे देश का बहुत ज्यादा भाग एकीकृत राज्य के अधीन में आ गया।'),
#  (<function __main__.<lambda>(x)>,
#   'भारतीय जीवन-धारा में जिन ग्रन्थों का महत्वपूर्ण स्थान है उनमें पुराण भक्ति-ग्रंथों के रूप में बहुत महत्वपूर्ण माने जाते हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'फास्ट ट्रेक कोर्ट - ये अतिरिक्त सत्र न्यायालय है इनक गठन दीर्घावधि से लंबित अपराध तथा अंडर ट्रायल वादों के तीव्रता से निपटारे हेतु किया गया है'),
#  (<function __main__.<lambda>(x)>,
#   'सिजिस्तान के अबू याकूब ने अपनी पुस्तक ? कश्फ़-उल-महजूब ?  रहस्योद्घाटन  में कहा है कि प्रजातियां या योनियां सुरक्षित रहती हैं और पुनर्जन्म का क्रम हमेशा एक ही प्रकार की योनियों में होता है  न वह कभी अपनी सीमा का अतिक्रमण करता है और न ही दूसरी योनियों में जाता है '),
#  (<function __main__.<lambda>(x)>,
#   'स्थायी तरंगित आकर्षक बड़ी इमारतो के आकार के'),
#  (<function __main__.<lambda>(x)>,
#   'विभिन्न कीट चींचीं  खड़खड़  किकियाने  सीटी और कर्कश चीख जैसी आवाजें पैदा करते हैंऐसा या तो जीवन के आनंद की अभिव्यक़्ति के रूप में या अपने मित्रों से संपर्क करने के साधन के रूप में या शत्रुओं को चेतावनी देने के लिए करते हैं '),
#  (<function __main__.<lambda>(x)>, 'हर पाँच साल में'),
#  (<function __main__.<lambda>(x)>,
#   'बर्मा और सीलोन पर वह जब तक हो सकता हैं  अपना कब्जा बनाये रखना चाहता'),
#  (<function __main__.<lambda>(x)>,
#   'विष्णुसहस्रनाम विष्णु के  नामों की महिमा शांतिपर्व में।'),
#  (<function __main__.<lambda>(x)>, 'और यह तरीका कारगर रहा '),
#  (<function __main__.<lambda>(x)>,
#   '=स्तुतः पौधों तथा जानवरों के सभी समूहों और उनके अन्दर होने वाले प्राकृतिक परिवर्तनों को  जीवन-विज्ञान संग्रह में प्रस्तुत किया गया है '),
#  (<function __main__.<lambda>(x)>,
#   'तकनीकी व्यक़्तियों की संख़्या भी कम थी और अधिकांश श्रमिक भी अस्थायी तौर पर नियुक़्त थे जो कि अधिक कार्यक्षमता की दृष्टि से लाभप्रद नहीं था '),
#  (<function __main__.<lambda>(x)>, 'नीले और मंद'),
#  (<function __main__.<lambda>(x)>,
#   'हालांकि जेल-अधीक्षक तथा अन्य अधिकांश स्थानीय अधिकारियों का रवैया ठीक थालेकिन बंगाल सरकार का रवैया  जो कि अपने कैदियों के भले-बुरे की खासतौर पर जिम्मेदार थी  प्रतिशोधपूर्ण था और भारत सरकार इस सबसे एकदम निस्पृह थी '),
#  (<function __main__.<lambda>(x)>, 'श्रेणीधर्म प्रवर्तक'),
#  (<function __main__.<lambda>(x)>,
#   'तो हम अपनी इमारतों को दिन के उजाले से प्रकाशित करते हैं'),
#  (<function __main__.<lambda>(x)>, 'कहाँ  कब वेब्साइट।'),
#  (<function __main__.<lambda>(x)>, 'और वह है कि उनके बच्चे कामयाब निकलें'),
#  (<function __main__.<lambda>(x)>, 'मैथुन'),
#  (<function __main__.<lambda>(x)>,
#   'इसके चलते सुप्रीम कोर्ट ने खुद कुछ बन्धन इनके प्रयोग पे लगाये है'),
#  (<function __main__.<lambda>(x)>,
#   'विश्व के बारे में चिंपैंजी से भी कम जानते हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'तीनों ही अपनी योजनाओं और प्रस्तावों को सामने रखने के मामले में'),
#  (<function __main__.<lambda>(x)>,
#   'मसलन  कोका कोल कंपनी अब सार्वजनिक निर्गम लने से छूट चाहती है '),
#  (<function __main__.<lambda>(x)>,
#   'शरद जोशी और बिपिन देसाई सरीखे दिग्गज नेताओं की अगुआई में किसानों ने सरकार को धमकी दी कि अगर उसने फसल नष्ट की तो गंभीर नतीजे भुगतने होंगे '),
#  (<function __main__.<lambda>(x)>, 'अगर आप आकर्षक हैं तो ऐसा हो सकता है '),
#  (<function __main__.<lambda>(x)>, 'रॉयल चितवन राष्ट्रीय उद्यान'),
#  (<function __main__.<lambda>(x)>,
#   'यानी ह्क्का गुड़ेगुड़ने वालं के पास बातचीत के कई मुद्दे होंगे '),
#  (<function __main__.<lambda>(x)>,
#   'यह मौका था एक अहम शुरुआत की वर्षगां मनाने का  लेकिन फूलन देवी की हत्या और यूटीआइ घोटाले को लेकरौ उ ए बवाल पर प्रधानमंत्री की इस्तीफे की नाटकीय घोषणा के शोरशराबे के चलते इस पर किसी ने ध्यान नहीं दिया '),
#  (<function __main__.<lambda>(x)>, 'संस्कृत सामग्री '),
#  (<function __main__.<lambda>(x)>,
#   'इस प्रकार एक बार स्थिति बदल लेने से एक रन बन जाता है।'),
#  (<function __main__.<lambda>(x)>,
#   'लेकिन हम अपने गति के कारण यह भी जानते है कि हम कहाँ हैं |'),
#  (<function __main__.<lambda>(x)>,
#   'हालांकि सन्  से ही प्रमुख वामपंथी नेताओं के खिलाफ एक बड़ा षड्यंत्र केस चलाने की संभावना पर विचार किया जा रहा था  लेकिन उसका पहला प्रत्यक्ष संकेत लार्ड इरविन द्वारा भारत के राज़्य सचिव को भेजे गये  सितंबर  के एक तार में मिलता है '),
#  (<function __main__.<lambda>(x)>,
#   'दिल्ली पुलिस के विशेष प्रकोष् ने फैशन वाले कपड़ें के निर्यातक  वर्षीय राजेश भल्ल उर्फ टूटू नामक ऐसे व्यैक्त को गिरतार किया  जो गत छह माह से फरार था '),
#  (<function __main__.<lambda>(x)>,
#   'दमयन्ती अथवा नल दमयन्ती अरण्यकपर्व में एक प्रेमकथा।'),
#  (<function __main__.<lambda>(x)>,
#   'इससे पहले एबीसीएल के बुरी तरह असफल हो जाने से अमिताभ को गहरे झटके लगे थे।'),
#  (<function __main__.<lambda>(x)>, ' आप हमें यह भेजें '),
#  (<function __main__.<lambda>(x)>,
#   'पहाड़ों में ऊपर थे और फेय्न्मन ने मुझसे कहा'),
#  (<function __main__.<lambda>(x)>, 'श्रेणीआगरा'),
#  (<function __main__.<lambda>(x)>,
#   'नियमों में यह स्पष्ट उल्लेख है कि राजा को बड़ी सावधानी के साथ वादों का विचारण करना चाहिए और न्यायाधीशों की राय मानते हुए विधि के अनुसार निर्णय देना चाहिए '),
#  (<function __main__.<lambda>(x)>, 'लोग नए-नए वस्त्र सिलवाते हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'गुरु ने जैसे ही एक कंगन उठाया  वह उनके हाथ से फिसलकर नीचे नदी में गिर पड़ा '),
#  (<function __main__.<lambda>(x)>,
#   'सचाई इसी अति उदासीनता और अतिशय प्रतिक्रिया के बीच कहीं छिपी ही है और उसी के ऊपर बंगाल के निर्दोष नागरिकों का भविष्य अटका हा है '),
#  (<function __main__.<lambda>(x)>, 'हमने उनकी आलोचना की'),
#  (<function __main__.<lambda>(x)>,
#   ' रेज़िडेंशल होम या नर्सिंग होम जाने के बारें में अधिक जानकारी  “ रेज़िडेंशल या नर्सिंग होम का चयन ” - छ्होओसिन्ग् अ षेसिडेन्टिअल् ओर् नुर्सिन्ग् होमे की पत्रिका में'),
#  (<function __main__.<lambda>(x)>,
#   'बकरी के दूध की विशेष गन्ध के कारण अनेक लोगों में इसके प्रति अरुचि होती है '),
#  (<function __main__.<lambda>(x)>,
#   'वे हिन्दुस्तान सोशलिस्ट रिपब्लिकन एशोसिएशन के स्थापक सदस्यों में से एक थे।'),
#  (<function __main__.<lambda>(x)>,
#   'अगर छठी कांग्रेस की रिर्पोट व विचारधारा लेनिन के उच्चतम विवेक से प्रदर्शित करती है तब जहां तक उपनिवेश  विशेषकर भारत  का प्रश्न है  लेनिन जिनोवि  बुखारिन  स्टालिन सभी अपनी बार लेनिन विरोधी साम्रज़्यवाद के सामाजिक जनवादी पिट्ठू रहे है और यही दरअसल उपनिवेशवाद पर तथा छठी कांग्रेस की अन्य समस्याओं से संबंधित प्रस्ताव का उदेश्य है '),
#  (<function __main__.<lambda>(x)>,
#   ' ये पीठे क्षेत्र के राज नैतिक दबाव मे आ जायेगी'),
#  (<function __main__.<lambda>(x)>,
#   'क्योंकि गैर-तकनीकी साहित्य में इसकी स्पष्ट व्याख्या नहीं है इसलिए सम्बन्धित रोगों के अनेक स्वरूपों के बीच अन्तर स्पष्ट करना होगा विश्व स्वास्थ्य संगठन डब्ल्यूएचओ के अनुसार इन्हे एसबेस्टोसिस asbestosis फेफड़ों के कैंसर और मेसोथेलिओमा mesotheliomaआम तौर पर एक बहुत ही दुर्लभ कैंसर के रूप में परिभाषित कर सकते हैं जब ये अधिक व्यापक हो जाते हैं तब ये अधिकतर एसबेस्टस से सम्बन्धित ही रहते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'सृ्ष्टि के अवशेषों के माध्यम से यह अनुमान लगाने का प्रयास करेंगे कि आरंभ में क्या हुआ था'),
#  (<function __main__.<lambda>(x)>, 'स्पीकर प्रोटेम [कार्यवाहक]'),
#  (<function __main__.<lambda>(x)>,
#   'मैमोग्राफ  एक्स रे  करने से वक्ष की और भी कई तरह की समस्याओं जो कि कैंसर नहीं हो सकती उनका पता लग जाता है |भाष्;'),
#  (<function __main__.<lambda>(x)>, 'विश्व सुधार अत्यधिक प्रासंगिक होना चाहिए'),
#  (<function __main__.<lambda>(x)>,
#   'इन शहरों में ज़्यादा तोड-फोड़ नहीं हुई दिखती  लेकिन इन शहरों में वह चहल-पहल कहां जो पहले होती थी '),
#  (<function __main__.<lambda>(x)>,
#   'आपको ध्यान है हैमलेट? पहला ऐक्ट तीसरा सीन'),
#  (<function __main__.<lambda>(x)>, 'अमोनिया उड जाती है'),
#  (<function __main__.<lambda>(x)>, 'वो समकालीन आंकडें लेते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'वर्ल्ड गैज़ेटियर द्वारा  में किये गये गणना कार्यक्रम के अनुसार मुंबई की जनसंख्या  थी।'),
#  (<function __main__.<lambda>(x)>, 'कि आपके पास हमेशा दो विकल्प होने चाहिए'),
#  (<function __main__.<lambda>(x)>,
#   'काफी हद तक उसे निष्पक्षता की वही भूमिका निभानी होती है जो अध्यक्ष निभाता है '),
#  (<function __main__.<lambda>(x)>, 'ग्रन्थसूची'),
#  (<function __main__.<lambda>(x)>,
#   'इस अवसर पर दिए गए उनके भाषण में उनके इस गुण को देखा जा सकता है।'),
#  (<function __main__.<lambda>(x)>,
#   'अनऋ-ऊण्श्छ्ष्-य प्रकार भिनऋ-ऊण्श्छ्ष्-न भिनऋ-ऊण्श्छ्ष्-न समयों पर होने वाले उतऋ-ऊण्श्छ्ष्-सवों के लिए उतऋ-ऊण्श्छ्ष्-सव मंडप हैं  जहां उतऋ-ऊण्श्छ्ष्-सव मूर्तियां सजाऋ जातीं  पूजी जातीं और जुलूस के रूप में बाहर लाऋ जातीं '),
#  (<function __main__.<lambda>(x)>,
#   'बकरे काटे जाZते हैं  शराब खूब पी जाती हैस्त्रियों छोटे-छोटे वर्तन  औलियां  गोलू से पोतकर लाल रंग से उस पर चित्र कारी पुजती है '),
#  (<function __main__.<lambda>(x)>, 'पृष्ठ  देखें'),
#  (<function __main__.<lambda>(x)>, 'मेरा चुनाव होगा चंद्रमा पर पानी मिलना |'),
#  (<function __main__.<lambda>(x)>, 'श्रेणीहिन्दी'),
#  (<function __main__.<lambda>(x)>,
#   'मिशनरी आसान में प्रेमी युगल; गुस्टाव लिम्ट '),
#  (<function __main__.<lambda>(x)>, 'उस  हफ्तों के लिए अकेले पालक है ?'),
#  (<function __main__.<lambda>(x)>,
#   'इन नयी तकनीकों के आगमन से शरीर के बाहर किसी पात्र में उत्परिवर्तन करना संभव हो गया हैZ तथा ऐसा करना कोई संयोग से होने वाली घटना नहीं हेयह किसी योजनाबद्ध तरीके से करवाया जा सकता है '),
#  (<function __main__.<lambda>(x)>,
#   'इन कारीगरों को अपने काम के लिये नकद भुगतान नहीं होता थावरन् फसल के बाद परंपरागत तरीके से उत्पादन का एक निश्चित हिस्सा मिलता था '),
#  (<function __main__.<lambda>(x)>,
#   'इस संबंध में जब लार्ड कर्जन से सलाह ली गई तो उन्होंने बताया कि भारत में ऐसे कई लोग हैं जो रवीन्द्रनाथ से कहीं अधिक महत्वपूर्ण हैं '),
#  (<function __main__.<lambda>(x)>,
#   'पृथ्वी की बाहरी सतह outer surface कई कठोर खंडों या विवर्तनिक प्लेट में विभाजित है जो क्रमशः कई लाख सालों many millions of years की अवधी में पूरे सतह से विस्थापित होती है सतह का करीब % नमक जल salt-water के सागर से आच्छादित है शेष में महाद्वीप और द्वीप ; तरल पानी अवस्थित हैं जो सभी ज्ञात जीवन के लिए आवश्यक है जिसका अन्य ग्रह के सतह पर अस्तित्व ज्ञात नही है पृथ्वी का आतंरिक सतह एक अपेक्षाकृत ठोस भूपटल mantle की मोटी परत के साथ सक्रिय रहता है एक तरल बाहरी कोर जो एक चुम्बकीय क्षेत्र और एक ठोस लोहा का आतंरिक कोर inner core को पैदा करता है'),
#  (<function __main__.<lambda>(x)>,
#   'तब आरंभिक बीसवीं शताब्दी में यहां सबसे पुरानी फिल्म प्रसारित हुयी थी।'),
#  (<function __main__.<lambda>(x)>,
#   'लंबा-चौड़ा यही मुल्क हम सबके लिए  जो यहां रहते हैं  हिंदुस्तान है  भारत माता है '),
#  (<function __main__.<lambda>(x)>,
#   'फिर भी इसके प्रयत्न जारी हैं और सफ़ाई की अनेक परियोजनाओं के क्रम में नवंबर में भारत सरकार द्वारा इसे भारत की राष्ट्रीय नदी तथा इलाहाबाद और हल्दिया के बीच  किलोमीटर गंगा नदी जलमार्ग- को राष्ट्रीय जलमार्ग घोषित किया है।'),
#  (<function __main__.<lambda>(x)>,
#   'पिर   भी  उनका कोई एक अखिल भारतीय संवर्ग नहीं है '),
#  (<function __main__.<lambda>(x)>, 'दुनिउया का लोकशाही केंद्र'),
#  (<function __main__.<lambda>(x)>,
#   'बुनकरों को अपनी और आकर्षित करने की होड़ में बंगाल मिलों ने इतनी मजदूरी देनी शुरू की जो दूसरे बुनाई उद्योगों के लिए देना असंभव था और परिणामस्वरूप इन उद्योगों को बंगाल से बाहर जाना पडा '),
#  (<function __main__.<lambda>(x)>,
#   'परंतु यदि कोई दोष जन्म के तुरंत बाद दिखाई देने लगता है तथा इतना गंभीर होता है कि रोग पीड़ित व्यक्ति प्रजनन के योग़्य नहीं रहते तो उन व्यक्तियों का बंध्याकरण उचित नहीं लगता हंसिया रोग इसी तरह की एक रोग है '),
#  (<function __main__.<lambda>(x)>,
#   'अपनी गलतियों के बारे में सोचने से बचने के लिए'),
#  (<function __main__.<lambda>(x)>,
#   'संस्कृत_ओसीआर से प्राप्त रोमन आउटपुट को देवनागरी में बदलने का दूसरा प्रोग्राम'),
#  (<function __main__.<lambda>(x)>,
#   'शिक्षा  बुद्धि चरित्र और उपलब्धि के मामलों में उनकी तुलना केवल सर्वोच्च अंग्रेज राजनेता से की जा सकती है  जबकि कोई भी भारतीय क्षण भर के लिए भी संदेह नहीं कर सकता कि सार्वजनिक जीवन में उनके शामिल होने का एक मात्र लक्ष्य मातृभूमि के प्रति उनकी संबंद्धता और उनका प्रेम था '),
#  (<function __main__.<lambda>(x)>, 'कमाल है'),
#  (<function __main__.<lambda>(x)>,
#   'अधिक अवधि के लिए किये जाने वाले व्यायाम के दौरान तथा उसके बाद रक़्त में ग़्लूकोज की मात्रा काफी कम हो सकती है '),
#  (<function __main__.<lambda>(x)>, 'एक और दो पालक वाले परिवार '),
#  (<function __main__.<lambda>(x)>,
#   'लडकियों को स्कूल कैसे भेजा जा सकता था क़्योंकि इसका अर्थ होता सार्वजनिक स्थानों से गुजरना और पुरूषों से संपर्क '),
#  (<function __main__.<lambda>(x)>,
#   'इसी बीच गेंदबाज की टीम के अन्य सदस्य मैदान में क्षेत्ररक्षक के रूप में अलग अलग स्थितियों में खड़े रहते हैं ये खिलाड़ी बल्लेबाज को दौड़ बनाने से रोकने के लिए गेंद को पकड़ने का प्रयास करते हैं और यदि सम्भव हो तो उसे आउट करने की कोशिश करते हैं।'),
#  (<function __main__.<lambda>(x)>, 'और अपनी पहचान को बदलते भी रह सकते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'नियमित शारीरिक कसरतों से वजन नियंत्रण में रहता है तथा रक्त का संचरण एवं हृदय का संचालन भी सुचारु रूप से होता है '),
#  (<function __main__.<lambda>(x)>,
#   'एप्पल टी वि संस्करण से अलग प्रयोगकर्ता अपने यू ट्यूब अकाउंट में लोग इन नही कर सकता पर सिर्फ़ आई फ़ोन के लिए एक अलग पसंदीदा सूची बना सकता hai'),
#  (<function __main__.<lambda>(x)>,
#   'और क्योंकि मुझे ये अजीब लगा था मैं उनसे मिलने चली गयी'),
#  (<function __main__.<lambda>(x)>,
#   'यह कहानी चल रही है आदान-प्रदान की कलाआप मुझ से बात कर सकते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'मैं नहीं कह रहा कि यह बिल्कुल नहीं पहुँच रहा।'),
#  (<function __main__.<lambda>(x)>,
#   'आश्विन शुक्ल दशमी को विजयादशमी का त्यौहार मनाया जाता है।'),
#  (<function __main__.<lambda>(x)>,
#   'जो अफगानिस्तान के निकट है की अोर संकेत करते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'इन व्यक्तियों की नियुक्ति केंद्र सरकार द्वारा की जाती है और ये अपने नियुक्ति आदेश में उल्लिखित अवधि के लिए पद धारण करते हैं  पर यह अवधि पांच वर्ष से अधिक नहीं हो सकती '),
#  (<function __main__.<lambda>(x)>,
#   ' उदयपुर मेवाड़ के प्राचीन राज्य की ऐतिहासिक राजधानी है और वर्तमान में उदयपुर जिले का प्रशासनिक मुख्यालय है।'),
#  (<function __main__.<lambda>(x)>,
#   'कुछ वीडियॊ उन्हीं उपयॊगकर्तॊं के लिए हैं जिनकी उम्र  साल या इससे अधिक है  जैसे आपराधिक सामग्री वाले वीडियॊ अश्लील साहित्य pornography नग्नता nudity मानहानि defamation उत्पीड़न harassment वाणिज्यिक और विज्ञापन सामग्री advertisementsऔर आपराधिक व्यवहार कॊ बढ़ावा देने वाली सामग्री वाले वीडियो अपलॊड करना criminal conductनिषिद्ध है '),
#  (<function __main__.<lambda>(x)>,
#   'हिमालय के ऊपरी भाग में इसमें टोंस तथा बाद में लघु हिमालय में आने पर इसमें गिरि और आसन नदियाँ मिलती हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'इसके लिए अभी और चिकित्सकीय परीक्षणों की जरूरत है '),
#  (<function __main__.<lambda>(x)>, 'वीडियो रैंकिंग'),
#  (<function __main__.<lambda>(x)>, 'और कुछ अवसादपूर्ण हैं जैसे नाइजीरिया में'),
#  (<function __main__.<lambda>(x)>, 'परिणाम कुछ हास्यकारक हो सकते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'सम्भवतः तिब्बती-बर्माई मूल के लोग नेपाल मे  वर्ष पहले आ चुके थे।'),
#  (<function __main__.<lambda>(x)>,
#   'इसलिए आधुनिक फैक़्ट्री निर्माता के रूप में इसका पुनर्जन्म  भरतीयों के लिए उज़्ज़्वल भविष्य के दर्शन के साथ अतीत के गौरव का पुनरूत्थान था '),
#  (<function __main__.<lambda>(x)>,
#   'और अंत में  ऊर्जा के वैकल्पिक स्रोतों की वास्तविक सामाजिक लागत को दर्शाते तर्कसंगत ऊर्जा  मूल्यों के निर्धारण की केवल बातें ही होती रही हैं काम कुछ नहीं हुआ है '),
#  (<function __main__.<lambda>(x)>,
#   'ऐसे डीलर से सावधान रहिए जो किसी कार के इतिहास को गुप्त रखने की कोशिश करता हुआ आए '),
#  (<function __main__.<lambda>(x)>,
#   'लोगों को एक चीज़ को सूँघने से रोकना  हो सकता है उन्हें उन पदार्थों को सूँघने की ओर मोड़ दे  जो ज़्यादा ख़तरनाक होंगे '),
#  (<function __main__.<lambda>(x)>, 'जो मैंने करीब एक साल पहले लगाया था -'),
#  (<function __main__.<lambda>(x)>,
#   'कारावासों  निर्वासनों ओर रोगों ने तुम्हारी क्षमताओं को बहुत हलकान किया  मगर उन्हें क्षति पहुंचाना तो दूर  उन पीड़ाओं ने तुम्हारी संवेदनाओं को विस्तार दिया  जिससे तुम्हारी दृष्टि व्यापक हुई और तुम क्षेत्रीय संकीर्णताओं से परे रहकर इतिहास के विराट परिप्रेक्ष्य को हृदयंगम कर सके    मुझे लगता है  तुम अपनी मातृभूमि के लिए नयी रोशनी और उम्मीद के संदेशवाहक बनकर आये हो '),
#  (<function __main__.<lambda>(x)>,
#   'इनमें गरीबी बेरोजगारी गिरता जन-स्वास्थ्य और अशिक्षा/असाक्षरता प्रमुख हैं।'),
#  (<function __main__.<lambda>(x)>, 'यही कारण है कि वह गिरता है'),
#  (<function __main__.<lambda>(x)>,
#   'और मुझे समझ आया कि धैर्यवान पूँजी की भावात्मक महत्ता क्या है'),
#  (<function __main__.<lambda>(x)>,
#   'तो अमी तबर ने इसे एक एकड के आठवें भाग जितने बडे खेत में लगाने लायक बनाया।'),
#  (<function __main__.<lambda>(x)>, 'बाहरी कड़ियाँ'),
#  (<function __main__.<lambda>(x)>,
#   'यह छात्र शायद पहली बार इसे उपयोग कर रहा है एक जटिल हस्त कौशल का काम कर रहा है'),
#  (<function __main__.<lambda>(x)>,
#   'और उन्हें बार बार आश्र्वासन दें कि सभी कुछ ठीक हो जायेगा '),
#  (<function __main__.<lambda>(x)>,
#   'पहले पैरिस और लन्दन और न्यू योर्क दुनिया के सबसे बड़े शहर हुआ करते थे'),
#  (<function __main__.<lambda>(x)>,
#   'तो आदमी आज भी एक लकड़ी जला कर आग के सामने'),
#  (<function __main__.<lambda>(x)>,
#   'तो स्वीकार करने के लिए ये एक बहुत ही कठिन नमूना है |'),
#  (<function __main__.<lambda>(x)>,
#   'हम उन्हें ब्राउज़िंग और एक दूसरे को ब्राउज़ करना सिखाते पाया।'),
#  (<function __main__.<lambda>(x)>,
#   'उत्तेजित भीड़ द्वारा विदेशी कपड़ों की होली जलाना और उस पर खुश होने से उन्हें नफरत थीविद्यार्थियों को स्कूल और कालेज छोड़कर राजनीतिज्ञों के हाथ का खिलौने बनने पर भी वे बहुत दुखी थे '),
#  (<function __main__.<lambda>(x)>, 'बहुत खतरनाक हो सकता है '),
#  (<function __main__.<lambda>(x)>,
#   'विगत कुछ वर्गो में इस दिशा में लिया गया स्वागत योग़्य कदम यह है कि नेशनल बुक ट्रस्ट लेखकों के अल्पकालीन शिविर आयोजित करते रहा है  जिसमे विभिन्न क्षेत्रीय भाषाओं के लेखक भाग लेते रहे और अपने आदान-प्रदान कार्यक्रम के अंतर्गत  प्रत्येक भाषा की कुछ चुनी हुई पुस्तकों का अन्य सभी भाषाओं मे प्रकाशन करते रहे हैं '),
#  (<function __main__.<lambda>(x)>,
#   'इन्हें अपर सत्र न्यायाधीश अथवा सहायक सत्र न्यायाधीश कहा जाता है ; ये सब उसी न्यायालय के न्यायाधीश होते हैं '),
#  (<function __main__.<lambda>(x)>,
#   'अस्तबल इस तरीके से बनाये जाने चाहिएं कि खराब मौसम  अत्यधिक गर्मी  ठंड और वर्षा से उनका बचाव हो जाये '),
#  (<function __main__.<lambda>(x)>,
#   'अतः उनकी परीक्षा करने के लिये द्रुपद ने उन्हें अपने राजप्रासाद में बुलाया।'),
#  (<function __main__.<lambda>(x)>,
#   'मतलब मैं कहती रही हूँ कि मैं तैयारी कर रही हूँ'),
#  (<function __main__.<lambda>(x)>,
#   'फैस्टिवल पाठ से वाक - फ़ेस्टिवल - हिन्दी का पाठ-से-वार्ता प्रोग्राम डाउनलोड'),
#  (<function __main__.<lambda>(x)>,
#   'आप देखेंगे कि शुरू के दिनों में कोई पचास-एक बरस पहले Zकुछ बड़े बड़े रईस लोग आपस में बैठकें किया करते थे और वफादार रहने की अजीबो-गरीब बातें किया करते थे '),
#  (<function __main__.<lambda>(x)>,
#   'प्राय  अनाज देने से पहले घोड़े को सूखी घास खिलायी जाती है '),
#  (<function __main__.<lambda>(x)>, 'मुझे एक भी महिला मदद करने को तैयार नहीं?'),
#  (<function __main__.<lambda>(x)>, 'मैंने उन्हें “द अंकल फोन” बना दिया |'),
#  (<function __main__.<lambda>(x)>, 'बच्चन के श्रेष्ठ कविताओं का संकलन'),
#  (<function __main__.<lambda>(x)>,
#   'हिन्दुओं का कोई केन्द्रीय चर्च या धर्मसंगठन नहीं है और न ही कोई पोप।'),
#  (<function __main__.<lambda>(x)>, 'एक पंछी की तरह उड़ान भरना'),
#  (<function __main__.<lambda>(x)>,
#   'यहां तक कि स्वदेशी वालं के लिए सबसे पवित्र क्षेत्र रक्षा उत्पादन को भी कुछ किंतु-परंतु के साथ खोल दिया गया है '),
#  (<function __main__.<lambda>(x)>, 'मुजफ्फरपुर'),
#  (<function __main__.<lambda>(x)>,
#   'हनुमान ने अशोकवाटिका का विध्वंस करके रावण के पुत्र अक्षय कुमार का वध कर दिया।'),
#  (<function __main__.<lambda>(x)>,
#   ' जब ट्रैफीक रुक जाये तो सडक पार करीये लेकिन तब भी आजुबाजु देखीये और सुनीये'),
#  (<function __main__.<lambda>(x)>,
#   'वे सारा दोष सरकार पर ही मढे देते हैं कि पहले तीन महीनों में सरकार ने बुनियादी सुविधाएं जुटाने में देर की    हम जुलई में ही काम शुरू कर पाए   '),
#  (<function __main__.<lambda>(x)>,
#   'कृष्ण जीवन सान्याल को धारा -ए के अंतर्गत एक साल के सपरिश्रम कारावास का दंड दिया जाता है '),
#  (<function __main__.<lambda>(x)>,
#   'गांवों में तो यही प्रणाली Zसुविधाजनक रहती है '),
#  (<function __main__.<lambda>(x)>,
#   'भारत के लिए चावला की आखिरी यात्रा - के नए साल की छुट्टी के दौरान थी जब वे और उनके पति परिवार के साथ समय बिताने गए थे।'),
#  (<function __main__.<lambda>(x)>,
#   'भत-से तेजड़ियों ने मुनाफे के आकांक्षी बैंकरों से गारंटी और चेक आदि लेकर जमा कर दिए   '),
#  (<function __main__.<lambda>(x)>,
#   'यह है भारत और बेशक इससे भी ज्यादा अचंभित करने वाला है'),
#  (<function __main__.<lambda>(x)>,
#   'प्रकाश संश्लेषण के विकास ने सूर्य की उर्जा का प्रत्यक्ष जीवन में उपयोग करने की अनुमति दी परिणामतः ऑक्सीजन वातावरण में संचित हुआ और ओजोन ऊपरी वायुमंडल में आणविक ऑक्सीजन [o] का एक प्रकार  की एक परत के रूप में परिणत हुआ बड़ी कोशिकाओ के साथ छोटी कोशिकाओं के समावेश के परिणामस्वरुप युकार्योतेस development of complex cells कहे जाने वाले जटिल कोशिकाओं का विकास में हुआ कोलोनियों के अंतर्गत सच्चे बहु कोशिकीय जीवो के रूप में वर्धमान विशेषीकृत होता है ओजोन परत ozone layer द्वारा हानिकारक पराबैंगनी विकिरण के अवशोषण से सहायता प्राप्त जीवन पृथ्वी पर संघनित हुआ'),
#  (<function __main__.<lambda>(x)>,
#   'दिल्ली खामोशी का जामा संसद के गहमागहमी भरे मानसून सत्र के दो हते बाद भी विपक्ष की नेता सोनिया गांधी अभी तक सुर्खियों में नहीं आईं '),
#  (<function __main__.<lambda>(x)>,
#   'धातुखंड पर टकसाल की मोहर होने से ही बाहर उसकी सिक़्के के रूप में स्वीकृति है '),
#  (<function __main__.<lambda>(x)>,
#   'कभी कभी केवल भारत कहा जाने वाला यह काव्यग्रंथ भारत का अनुपम धार्मिक पौराणिक ऐतिहासिक और दार्शनिक ग्रंथ हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'ध्यान रखें कि इन मानकों को प्राप्त न करने का कनाडा में कोई महत्व नहीं है'),
#  (<function __main__.<lambda>(x)>,
#   'शरियत की निति को नींव बना कर न्यायशास्त्र के अध्य्यन को फिक़ह कहते हैं।'),
#  (<function __main__.<lambda>(x)>, 'जब मेरे माता-पिता कनाडा आये'),
#  (<function __main__.<lambda>(x)>,
#   'कि उन्हें अपने ही पैरों पर खड़े करने के लिए मदद करें।'),
#  (<function __main__.<lambda>(x)>,
#   'शिशिर गुप्त अ आरह सौ सत्तावन की आजादी की पहली लड़ई के बाद अंदमान-निकोबार द्वीप समूह अंग्रेज सरकार के लिए कैदियों को काल पानी की सजा देने की जगह थी '),
#  (<function __main__.<lambda>(x)>, 'दर्शनीय स्थल'),
#  (<function __main__.<lambda>(x)>,
#   'उन रिपोर्टों के बारे में कहा जाता है कि ये शार्टहैंड से ली गयी हैं  लेकिन ये रिपोर्टें मुकम्मिल नहीं  ये अधूरी हैं  ये साफ नहीं हैं और कहीं कहीं से तो कोई मायने भी नहीं निकलते हैं '),
#  (<function __main__.<lambda>(x)>,
#   'रवाना होने में देरी होना या रवाना न हो पाना ;'),
#  (<function __main__.<lambda>(x)>,
#   'इसलिये हम यूनाइटेड किन्गडम्\u200c जैसे देशों के मुकाबले भी'),
#  (<function __main__.<lambda>(x)>,
#   'तत्पश्चात उन्हें उठाकर घर में सभी स्थानों पर रखा जाता है '),
#  (<function __main__.<lambda>(x)>,
#   'इसी कारण पौधों का विकास पृथक रूप में होकर उनके बाह्य रूप भिन्न हो जाते हैं '),
#  (<function __main__.<lambda>(x)>,
#   'गुणसूत्रों की जोड़ी के कारण जो स्थिति उत्पन्न होती है वह अलिंगी जीनों की जोड़ी से अथवा स्त्री के लिंग गुणसूत्रों की जोड़ी से उत्पन्न होने वाली Zस्थिति से भिन्न होती हैस्त्री के लिंग गुणसूत्रों की जोड़ी में दो ध् गुणसूत्र होते हैंयदि Y गुणसूत्र को ध् गुणसूत्र के साथ साथ मिलाया जाये तो  जैसा चित्र- में दिखाया गया है  हम देखेंगे कि लंबा ध् गुणसूत्र तीन खंडों में विभाजित हो सकता है '),
#  (<function __main__.<lambda>(x)>,
#   'बाह्य रूप से चतुर्भुज खुला प्रांगण एक प्राकार से घिरा होता है जिसमें एक विहार  या मालिका होती है जिसे स्थानीय रूप से नलांबलम या चुट्टांबलम कहा जाता हैं '),
#  (<function __main__.<lambda>(x)>,
#   'ये मोडल्स द्रव गतिशीलता के भौतिक सिद्धांतों विकरणशील हस्तांतरण radiative transfer और अन्य प्रक्रियाओं पर आधारित हैं कटी जगाहाओं पर सरलीकरण किया गया है क्यूंकि कंप्यूटर की अपनी सीमाएं होती हैं और जल्यायु प्रणाली बहुत ही जटिल complexityहै सरे आधुनिक जलवायु मॉडल अपने में एक वतावार्नेय मॉडल लिए होते हैं और यह समुद्र के मॉडल और भूमि तथा समुद्र पर बर्फ के मॉडल के साथ जुदा होता है कुछ मॉडलों में रासायनिक और जैविक प्रक्रियाओं के उपचार भी शम्मिल होते हैं यह मॉडल पता लगाते हैं कि ग्रीनहाउस गैसों का प्रभाव अगर जोड़ा जाए तो एक गर्म जलवायु प्राप्त होती है फिर भी जब ये धारणा इस्तेमाल की जाती है तो भी जलवायु संवेदनशीलता climate sensitivity का बहुत बड़ा रोल रहता है'),
#  (<function __main__.<lambda>(x)>,
#   'वे सुस्थापित रूप हैं जो इतनी अच्छी तरह से अनुकूलित हो गए हैं कि अपने ग्रामीण संबंधियों के पास आकस्मिक रूप से जाने का न तो प्रयास करते हैं और न जा ही सकते हैं '),
#  (<function __main__.<lambda>(x)>,
#   'न्यायाधीश  एडवोकेट जनरल  सैन्य अफसर और राजनीतिक नेतासभी इस यादगार बयान को कान लगाकर ध्यान से सुन रहे थे '),
#  (<function __main__.<lambda>(x)>,
#   'गुम्बद एवं छतरियों के शिखर पर परंपरागत फारसी एवं हिंदू वास्तु कला का प्रसिद्ध घटक एक धात्विक कलश किरीटरूप में शोभायमान है।'),
#  (<function __main__.<lambda>(x)>,
#   'ह्यहृ दलगतरहित  निष्पक्ष दृष्टिकोणऋएक संसदीय अधिकारी को सभी इऋयाकलापों में भाग लेते हुए भी निर्लेप होना चाहिएL और ह्यहृ ऐसे समाधान ढूंढऋने की योग्यता जो केवल सैद्धांतिक रूप से ही सही न हो बल्कि व्यावहारिक भी होंसंसद के सचिवालय गतिशील और विकासशील संस्थाएं हैं ऋनके लिए अपेक्षित है कि वे सांसदों की बढऋती हुऋ एवं परिवर्तनशील आवश्यकताओं को पूरा करे '),
#  (<function __main__.<lambda>(x)>,
#   'कभी कभी आंखें और नाक पीले रंग के पनीले स्राव से ढंप जाती हैं '),
#  (<function __main__.<lambda>(x)>,
#   'विश्वशांति में उल्लेखनीय योगदान के लिए बराक ओबामा को वर्ष  के नोबेल शांति पुरस्कार के लिए चुना गया है।'),
#  (<function __main__.<lambda>(x)>,
#   '? अरूट्पा ?  श्री कृपा-ग्रंथ  को मरूट्पा  अज्ञान का ग्रन्थ  कहा तथा असत्य-मार्ग की पुस्तक का खंडन नाक की पुस्तिका प्रकाशित की '),
#  (<function __main__.<lambda>(x)>,
#   'अगला मण्डप है दीवान-ए-खास जो राजा का मुक्तहस्त से सुसज्जित निजी सभा कक्ष था।'),
#  (<function __main__.<lambda>(x)>,
#   'कबीर के राम इस्लाम के एकेश्वरवादी एकसत्तावादी खुदा भी नहीं हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'लेकिन इससे भी बड़ी विपत्ति इस उद्योग पर अभी आने वाली थी '),
#  (<function __main__.<lambda>(x)>, 'वे सही रास्ते पर नहीं चल रहे हैं'),
#  (<function __main__.<lambda>(x)>, 'स्थान कम रह गया था।'),
#  (<function __main__.<lambda>(x)>,
#   ' की एक संधि के जरिए बेगम समरू ने ब्रिटिश संरक्षण स्वीकार कर लिया  जिससे उसे सुरक्षा तो मिली ही  वह अपनी संपैत्त भी लकोपकार में लगाने लगी '),
#  (<function __main__.<lambda>(x)>,
#   'ऐसे भी बाक्स पाचक विकसित किए गये हैं जो बरसात या धुंध के दिनों में बिजली से खाना पकाने हेतु प्रयोग किए जा सकते हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'यह युद्ध हजरत मुहम्मद सल्लल्लाहु अलैहि वसल्लम के ज़माने से चली आ रही दुश्मनी का हिस्सा थे।'),
#  (<function __main__.<lambda>(x)>,
#   'नेपाल का कुल क्षेत्रफल  वर्ग किलोमीटर है।'),
#  (<function __main__.<lambda>(x)>, 'कला के नमूनों को बनाने में |'),
#  (<function __main__.<lambda>(x)>, 'भारत मे अंतरजाल'),
#  (<function __main__.<lambda>(x)>,
#   'सन्  में  इनका हिस्सा  प्रतिशत था जो अभी ठीक ही था '),
#  (<function __main__.<lambda>(x)>,
#   'बहरहाल वह अपने इस सिद्धांत के द्वारा यह सिद्ध करना चाहता था कि अंडाणु का आधा भाग पृथ्वी के रूप में फैल गया और दूसरा आधा गुंबज की भांति उसके ऊपर स्थापित हो गया और इसमें भू-मंडल के तल-प्रक्षिप्त गोल के विवेचन में वह टॉल्मे का स्पर्धी बनना चाहता था  किंतु विफल रहा '),
#  (<function __main__.<lambda>(x)>, 'तमिळ'),
#  (<function __main__.<lambda>(x)>,
#   'प्रेमचंद हिन्दी साहित्य के युग प्रवर्तक हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'वह बदबू ज्होलकर बाबुओं की भीड़े को चीरते हे आप गलियारों में दाखिल होते हैं और उसके बाद आता है गर्भगृह यानी बड़े साहब का कमरा '),
#  (<function __main__.<lambda>(x)>, 'और यह मजबूत हो रही है '),
#  (<function __main__.<lambda>(x)>, 'नेपाल विक्षनरी'),
#  (<function __main__.<lambda>(x)>,
#   'लेकिन जब दकियानूसी ताकतों  तानाशाही और साम्राजऋ-ऊण्श्छ्ष्-यवाद की हार होने लगती है  तब बात अहम ढहो जाती है और इन संधियों को बरकरार रखने की पूरी कोशिश की जाती है  चाहे ये कितनी ही पुरानी क्यों न हों और इनसे जनता का चाहे ऋतना भी नुकसान कऋ-ऊण्श्छ्ष्-यों न होता हो '),
#  (<function __main__.<lambda>(x)>, 'रीवा'),
#  (<function __main__.<lambda>(x)>,
#   'अवैद या अनुचित - कुछ अधिकारी विशेषकर सरकार आतंकवाद की परिभाषा हरामीपन या अवैद की एक कसौटी जोड़ें कार्रवाई के बीच एक वैध सरकार द्वारा अधिकृत भेद करने के लिए और इस प्रकार  वैध है और उन व्यक्तियों और छोटे समूहों सहित अन्य अभिनेताओं केइस कसौटी कि अन्यथा आतंकवाद के तौर पर उचित नहीं होगा कार्यों का उपयोग आतंकवाद पर विचार नहीं किया जाएगा अगर वे थे सरकार को मंजूरी दे दीअगर यह एक वैध सरकार द्वारा अधिकृत किए गए उदाहरण के लिए जो एक कारण के लिए नागरिक समर्थन को प्रभावित करने के लिए डिज़ाइन किया गया है एक शहर है firebombing आतंकवाद पर विचार नहीं किया जाएगाइस कसौटी स्वाभाविक और समस्याग्रस्त है सार्वभौमिक स्वीकार किए जाते हैं नहीं है क्योंकि यह राज्य आतंकवाद state terrorismके अस्तित्व से इनकार करते हैं एक ही कार्य कर सकते हैं या आतंकवाद के रूप में है कि क्या इसके प्रायोजन एक वैध सरकार को पता है के आधार पर वर्गीकृत किया जा नहीं सकते हैं; वैधता और अवैद एक सरकार या किसी अन्य; और यह ऐतिहासिक स्वीकार किए जाते हैं अर्थ और इस शब्द का उद्गम से दिवेर्गेस के परिप्रेक्ष्य के आधार पर व्यक्तिपरक रहे हैंइस कसौटी सार्वभौमिक स्वीकार किए जाते हैं नहीं है इन कारणों के लिएशब्द का अधिकांश शब्दकोश परिभाषा इस कसौटी शामिल नहीं हैं'),
#  (<function __main__.<lambda>(x)>,
#   'वे  में उच्च शिक्षा प्राप्त करने के लिए इंग्लैंड गईं और पढ़ाई के साथ-साथ कविताएँ भी लिखती रहीं।'),
#  (<function __main__.<lambda>(x)>,
#   'प्रारम्भ में इस नहर में जलापूर्ति गंगा नदी में एक अस्थायी बॉंध बनाकर की जाती थी।'),
#  (<function __main__.<lambda>(x)>, 'एक \u200eमक्की भाग दूसरा मदनी भाग।'),
#  (<function __main__.<lambda>(x)>, 'निर्वाण प्राप्त करना'),
#  (<function __main__.<lambda>(x)>,
#   'अर्थात जब माया के आइने में ब्रह्म की छाया पड़ती है तो ब्रह्म का प्रतिबिम्ब हमें ईश्वर के रूप में दिखायी पड़ता है।'),
#  (<function __main__.<lambda>(x)>,
#   'तो यह पथ रेखाएं दर्शाती हैं कि हमारी अपेक्षा में लोग कैसे जियेंगे'),
#  (<function __main__.<lambda>(x)>,
#   'संसार की अधिकाश ऊँची पर्वत चोटियाँ हिमालय में ही स्थित हैं।'),
#  (<function __main__.<lambda>(x)>, 'नेवाडा'),
#  (<function __main__.<lambda>(x)>, 'धन्यवाद।'),
#  (<function __main__.<lambda>(x)>, 'मगर यदि आप इंगलिश के मूल-वक्ता नहीं हैं'),
#  (<function __main__.<lambda>(x)>,
#   'हम उन आवाजों को छोड़ देते हैं जो सामान रहती है |'),
#  (<function __main__.<lambda>(x)>,
#   'परिणामस्वरूप  अत्यधिक उन्नत किस्मों के उत्पादन में वृद्धि हो रही थीयद्यपि भूमि क्षेत्र कम हो रहा था '),
#  (<function __main__.<lambda>(x)>, 'अगली उपलब्धि है उस एक करोड़ को आधा करना'),
#  (<function __main__.<lambda>(x)>,
#   'बंगाल की खाड़ी में  वर्ग किमी में फैल यह द्वीप समूह विशेष किस्म के कछुओं और घने वनों के लिए प्रसिद्ध रहा है '),
#  (<function __main__.<lambda>(x)>,
#   'अगर हम चाहते तो अपनी बात मनवाकर पाकिस्तान को उस पर राजी करवा सकते थे '),
#  (<function __main__.<lambda>(x)>,
#   'वह मुसलमानों के प्रवक़्ता बने रहे और जानते थे कि जहां कहीं भी उसकी वैध शिकायतें हों  मुसलमानों द्वारा अन्य लोगों सेप्राप्त सहायता या सहानुभूति केवल मरहम हो सकती है  रोगमुक़्त नहीं कर सकती '),
#  (<function __main__.<lambda>(x)>, 'होड़ चली है'),
#  (<function __main__.<lambda>(x)>,
#   'यदि हम खरीद पाने लायक मूल्य में उन्हें साहित्य उपलब्ध कराएं'),
#  (<function __main__.<lambda>(x)>,
#   'नेहरू को छोड़कर और किसी भी राष्ट्र नेता के मन में यह चिंता नहीं थे '),
#  (<function __main__.<lambda>(x)>, 'अब तक उस पल तक'),
#  (<function __main__.<lambda>(x)>, 'हो सकता है हम अपने दिमागों'),
#  (<function __main__.<lambda>(x)>, 'क्योकि सारी जानकारी डीएनए के अंदर है'),
#  (<function __main__.<lambda>(x)>, 'अगर नाइकी एक जोडी जूते बेचना चाहता और'),
#  (<function __main__.<lambda>(x)>, 'श्रेणीजीवनी'),
#  (<function __main__.<lambda>(x)>,
#   'वसामय विशिष्ठताएं Sebaceous prominences फ़ोर्डाइस के धब्बे के समान ही शिश्न दण्ड पर वसामय ग्रंथियों में स्थित उभरे हुये छोटे धब्बे हैं और सामान्य हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'वहाँ पर बैठे हुए किसी व्यक्ति की तरफ देखते हुए और उनके कहीं और देखने का इंतेज़ार कर रहे हैं'),
#  (<function __main__.<lambda>(x)>,
#   'इनके लिए साफ और ताजे जल की सदैव व्यवस्था होनी चाहिए '),
#  (<function __main__.<lambda>(x)>,
#   'श्री हर्ष और विक्रमादित्य के काल में  वर्षों का अंतराल है और यह बात मुझे उस क्षेत्र के निवासियों ही ने बताई है '),
#  (<function __main__.<lambda>(x)>,
#   'छेड़े जाने या डराए जाने पर यह भृंग अपनी गुदा के सिरे से एक दुर्गंधयुक़्त और दाहक वाष्पशील द्रव जोरदार धमाके से निकालता है और भाग निकलता है तथा पीछे रह जाता है तीखे धुएं से पराजित एकदम भ्रमित शत्रु '),
#  (<function __main__.<lambda>(x)>, 'फायरफॉक्स हेतु हिन्दी वर्तनी जाँचक ऍडऑन'),
#  (<function __main__.<lambda>(x)>,
#   'अगर आप किसी विदेशी शाखा से अस्थाई तौर पर उस का स्थानांतरण कर दें या किसी विदेशाई नियोक्ता ने उस की आप के पास काम करने की सिफारिश करी है  तो इस के रोज़गार की विदेशी संविदा का ज़ारी रहना ही ठीक रहेगा '),
#  (<function __main__.<lambda>(x)>, 'ठहाके'),
#  (<function __main__.<lambda>(x)>,
#   'सरकार ने उसके उत्पादन का बड़ा अंश लगान और अन्य करों के रूप में ले लिया '),
#  (<function __main__.<lambda>(x)>,
#   'अपने पुलिस के कर्तव्यों के अतिरिक्त कोतवाल को कुछ न्यायिक शक्तियां थीं '),
#  (<function __main__.<lambda>(x)>,
#   'परंतु वे वास्तव में समाजवादी कम और अराजकतावादी तथा श्रमिक संघवादी अधिक थे '),
#  (<function __main__.<lambda>(x)>,
#   'मादक पदार्थों की लत हों तो आप बस और अधिक चाहते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'अंग्रेज़ी हिन्दी शब्दकोष पी॰डी॰ऍफ़॰ प्रारूप में'),
#  (<function __main__.<lambda>(x)>,
#   'वे चार किमी के उस परिक्रमा मार्ग के तीन-चार चक्कर लगाती हैं  जिसके किनारे  मूर्तियां रखी होती हैं '),
#  (<function __main__.<lambda>(x)>,
#   'एक अक्षौहिणी में हाथियों की संख़्या  होती है  रथों की संख़्या भी  होती है  घोड़ों की संख़्या  और मनुष्यों की संख़्या  होती है '),
#  (<function __main__.<lambda>(x)>,
#   'अगर मैं इस चक्की को घुमाऊं तो छोटा वाला तेज़ी से घूमेगा।'),
#  (<function __main__.<lambda>(x)>, 'ये असल में मैनें ईरान लौट कर बनाया था'),
#  (<function __main__.<lambda>(x)>,
#   'यह कहा जा सकता है कि ज़्यादातर ये बातें ऊपरी हैं और मूल बातें पकड़ने के लिए हमें वेदों को लेना चाहिए या हमारे दर्शनशास्त्र को '),
#  (<function __main__.<lambda>(x)>,
#   'या शायद संस्कृति में स्वयं अपनी दिलचस्पी न होने की वजह से वे यह न देख सके कि इंदिरा के नेतृत्व के कई वर्षों के दौरान   असीम और भमूल्य   स्मारकों को खंड़हर बनने दिया गया '),
#  (<function __main__.<lambda>(x)>,
#   'जापानी अधिपत्य के पूर्व अंग्रेजी शासनकाल का यहां पर अंतिम पदाधिकारी एक अंग्रेज था जिसका नाम स्कौट था '),
#  (<function __main__.<lambda>(x)>,
#   'कुछ प्रजातियां ताजे पानी में रहती हैं और पशुओं को काटती हैं जबकि कुछ प्रजातियां अन्य खारे पानी में रहती हैं और मनुष्यों को काटती हैं '),
#  (<function __main__.<lambda>(x)>, 'यकीन करिए या नहीं ये मैंने सीखे हैं'),
#  (<function __main__.<lambda>(x)>, 'हमारे दिमाग में काम की चीज़ है'),
#  (<function __main__.<lambda>(x)>,
#   'ऐतिहासिक Zहथियारों की लेकर स्थान-स्थान पर नृत्य भी किए जाते है '),
#  (<function __main__.<lambda>(x)>,
#   'प्राचीन चिकित्सा शास्त्रों में यह कहा गया है कि यदि किसी भी प्रकार के प्रमेह को उपेक्षित किया जाये तो अंतत  वह मधुमेह बन जाता है जो बाद में लाइलाज हो जाता है '),
#  (<function __main__.<lambda>(x)>,
#   'वेद बहुत ही जटिल तथा शुष्क भाषा-शैली में लिखे गए हैं।'),
#  (<function __main__.<lambda>(x)>,
# ...
#  (<function __main__.<lambda>(x)>, 'दैनिक जागरण  इ-पत्र यूनिकोड में '),
#  (<function __main__.<lambda>(x)>,
#   'तो हम ये कहना चाह रहे हैं कि विशाल बनने के चक्कर में'),
#  (<function __main__.<lambda>(x)>,
#   'यह सही है कि राज्य सरकार ने बड़ै पैमाने पर पुनर्निर्माण करवाया '),
#  (<function __main__.<lambda>(x)>,
#   'लेकिन हर बार जब आरक्षण की अवधि समाप्त हो जाती है तो सरकार अपने विवेकानुसार उसे और बढ़ाने का निश्चय करती है और उसके लिए संविधान के संबद्ध उपबंध में संशोधन कर देती है  अनुच्छेद   '),
#  (<function __main__.<lambda>(x)>,
#   'एक बल्लेबाज दस तरीके से आउट हो सकता है और कुछ तरीके इतने असामान्य हैं की खेल के पूरे इतिहास में इसके बहुत कम उदाहरण मिलते हैंआउट होने के सबसे सामान्य प्रकार हैं बोल्ड केच एल बी डबल्यू रन आउट स्टंपड और हिट विकेटअसामान्य तरीके हैं गेंद का दो बार हिट करना मैदान को बाधित करना गेंद को हेंडल करना और समय समाप्त'),
#  (<function __main__.<lambda>(x)>,
#   'ये ईमेल आपके अकाउंट में आ सकती है या कुछ और इंतज़ाम हो सकता है ।'),
#  (<function __main__.<lambda>(x)>,
#   'वह मुख़्य गलियारे को अंडों से निकलने वाले लार्वों के लिए काम में लाती है '),
#  (<function __main__.<lambda>(x)>,
#   'सम्राट का न्यायालय सर्वोच्च अपीली न्यायालय था  वह देश का सर्वोच्च अधिकरण था '),
#  (<function __main__.<lambda>(x)>,
#   'उनकी मांग है-जहां बाबरी मस्जिद थी वहां परौ राम मंदिर निर्माण की सभी बाधाएं सरकार  मार्च तक दूर करे '),
#  (<function __main__.<lambda>(x)>,
#   'यह काल समग्रतः भक्ति भावना से ओतप्रोत काल है।'),
#  (<function __main__.<lambda>(x)>,
#   'जो लोग बच्चा या फिर बच्चों की देखबाल करते है '),
#  (<function __main__.<lambda>(x)>,
#   'निचले त्रोपोस्फेरे troposphereमें तापमान  और  °C   और  °F के बीच में प्रति दशक बड़ा है जैसा की उपग्रह के आंकडे बताते हैं  satellite temperature measurementsयह माना जाता है कि  से पहले पिछले एक या दो हज़ार सालों one or two thousand yearsसे तापमान अपेक्षाकृत स्थिर रहा है कुछ क्षेत्रीये उतार -चडाव जैसे की मध्यकालीन गर्म काल Medieval Warm Period या अल्प बर्फीला युग Little Ice Age'),
#  (<function __main__.<lambda>(x)>, 'टाईपिंग करते हुए।'),
#  (<function __main__.<lambda>(x)>,
#   'ये हालात दिखाते हैं कि जहाज पर सावरकर की निगरानी के लिए मौजूद व्यक्ति यह सोचने की स्थिति में थे कि उन्हें फ्रांसिसी पुलिस की सहायता मिल सकती है '),
#  (<function __main__.<lambda>(x)>,
#   'ज़रूरी नहीं कि ये चीज़ें ख़ास ही हों ; मिलकर सिनेमा या फ़ुटबॉल का मैच देखने जाना या फिर साथ बैठकर सिर्फ़ टेलिविज़न देखना भी हो सकता है '),
#  (<function __main__.<lambda>(x)>,
#   'कृपया आप के झोब्चेन्ट्रे को संपर्क कर के कैसे आप के काम की शुरुवात हो सकती है इस के बारे में योजनाओं के बारे में अधिक जानकारी मालूम कर सकते है '),
#  (<function __main__.<lambda>(x)>,
#   'इसी बहाने अंग्रेज़ सरकार ने सुभाषबाबू को गिरफतार किया और बिना कोई मुकदमा चलाए उन्हें अनिश्चित कालखंड के लिए म्यानमार के मंडाले कारागृह में बंदी बनाया।'),
#  (<function __main__.<lambda>(x)>, 'और वह जाग खुद पर नज़र डालती है'),
#  (<function __main__.<lambda>(x)>,
#   'यह समिति संसद और संसद सदस्यों की शक्तियों और उनकी प्रतिष्ठा की रक्षा करने में महत्वपूर्ण भूमिका निभाती हैं '),
#  (<function __main__.<lambda>(x)>,
#   'क्योंकि डूडल बना पाना सबके लिये इतना आसान है'),
#  (<function __main__.<lambda>(x)>,
#   'शिव के स्पर्श से गंगा और भी पावन हो गयी और पृथ्वी वासियों के लिये बहुत ही श्रद्धा का केन्द्र बन गयीं।'),
#  (<function __main__.<lambda>(x)>,
#   'भारत आपरेटिंग सिस्टेम्स सालुशन या बॉस BOSS'),
#  (<function __main__.<lambda>(x)>,
#   'ये सपने हिंदुस्तान के बारे में हैं  ये दुनिया के बारे में हैं क़्योंकि आज सारे मुल्क और सारे लोग आपस में एक-दूसरे पर इस तरह बंधे हुए हैं कि कोई भी शांति के बारे में कहा जाता है कि उसके टुकड़े नहीं किये जा सकते  आजादी भी ऐसी ही चीज है  ऐसी ही अब खुशहाली है और इसी तरह इस दुनिया में संकट भी है  जो एक है और जिसे अलग अलग टुकड़ों में नहीं रखा जा सकता '),
#  (<function __main__.<lambda>(x)>, 'लंदन संयुक्त राजशाही'),
#  (<function __main__.<lambda>(x)>,
#   ' अक्टूबर  को बच्चने ने बाराबंकी जिले के दौलतपुर गांव की इस भूमि के दावे को छोड़ दिया।'),
#  (<function __main__.<lambda>(x)>,
#   'पादचारियों  साइकिल एवं मोटर साइकिल सवारों को दिन में चमकीले एवं रात में दिखने वाले कपड़े पहनने चाहिये '),
#  (<function __main__.<lambda>(x)>,
#   'एलीफेंटा की गुफाएं विश्व धरोहर स्थ घोषित हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'इसके द्वारा जिसे मेरे छात्र दादीमाँ का बादल granny cloud कहते हैं'),
#  (<function __main__.<lambda>(x)>,
#   'सिद्धार्थ ने दो ब्राह्मणों के साथ अपने प्रश्नों के उत्तर ढूंढने शुरू किये।'),
#  (<function __main__.<lambda>(x)>, 'असाधारण है रियली सिंपल सिंडिकेशन'),
#  (<function __main__.<lambda>(x)>,
#   'एक गुप्त योजना के तहत इन्होंने पुलिस सुपरिंटेंडेंट सैंडर्स को मारने की सोची ।'),
#  (<function __main__.<lambda>(x)>,
#   'अकबर का जन्म राजपूत शासक राणा अमरसाल के महल उमेरकोट सिंध वर्तमान पाकिस्तान में  नवंबर  हिजरी अनुसार रज्जब  के चौथे दिन हुआ था।'),
#  (<function __main__.<lambda>(x)>,
#   'मसौदा घोषणा  जिसमें गुलमी के लिए हर्जाने की मांग की गई है  से अमेरिका समेत कई देश परेशान हैं '),
#  (<function __main__.<lambda>(x)>,
#   'इस प्रकार के अधिकरणों के मुख्य कार्य सुलह- सफाई कराने के थे और स्थानीय शासक उनके कार्य में हस्तक्षेप नहीं करते थे '),
#  (<function __main__.<lambda>(x)>, 'मेरे और फेय्न्मन के रिश्तों के बारे में'),
#  (<function __main__.<lambda>(x)>,
#   'अगर मैच में हर पक्ष के लिए केवल एक पारी है तो हर पारी के लिए की अधिकतम गेंदों की संख्या अक्सर निश्चित कर दी जाती हैइस तरह के मैच सीमित ओवरों के मैच या एक दिवसीय मैच कहलाते हैं और विकेटों की संख्या को ध्यान में न रखते हुए अधिक रन बनाने वाली टीम जीत जाती है जिससे ड्रा नहीं हो सकता हैयदि इस प्रकार का मैच अस्थायी रूप से ख़राब मौसम के कारण बाधित हो जाता है तो एक जटिल गणितीय सूत्र जो डकवर्थ -लुईस पद्धति कहलाती है उसके मध्यम से एक नया लक्ष्य स्कोर फ़िर से आकलित किया जाता हैएक दिवसीय मैच को भी परिणाम रहित घोषित किया जा सकता है यदि किसी एक टीम के द्वारा पूर्व निर्धारित ओवर डाले जा चुके हैं और किसी परिस्थिती जैसे गीले मौसम के कारण आगे खेल को नहीं खेला जा सकता है'),
#  (<function __main__.<lambda>(x)>, 'प्रोपेन और बेंजीन'),
#  (<function __main__.<lambda>(x)>,
#   'ऐसी स्थिति में राजा को उस दाय में हस्तक्षेप करने का कोई अधिकार नहीं है  अलबत्ता उसे केवल भिक्षा-दान पर ही खर्च किया जाता है '),
#  (<function __main__.<lambda>(x)>,
#   'मगर उनके प्रतिद्वंद्वी कहते हैं कि वे दंभी हैं और खुद को आगे बढने का कोई मौका नहीं चूकते  जो आरएसएस की शैली के विपरीत है '),
#  (<function __main__.<lambda>(x)>,
#   'अब एशिया में अपनी यथोचित भैमका के लिए मुखर होकर बोलने का आत्मविश्वास भारत में आ गया है '),
#  (<function __main__.<lambda>(x)>, 'दाल बाटी'),
#  (<function __main__.<lambda>(x)>,
#   'पर आने के कुछ ही दिनों की भीतर मुझे बताया गया वो भी सीधे मेरे मुँह पर'),
#  (<function __main__.<lambda>(x)>,
#   'इसलिए मैं हिंदुओं और मुसलमानों सभी से अपील करता हूं कि वे आपस में एक हों और जल्दी से जल्दी अपनी ताकत को बढ़ायें '),
#  (<function __main__.<lambda>(x)>,
#   'क्योंकि उस से ही तो जीवन में प्रसन्नता आती है।'),
#  (<function __main__.<lambda>(x)>,
#   'इसके जवाब में उन्होंने कहा कि हां पुराना आलोक चला जाएगा नए का आगमन होगा।'),
#  (<function __main__.<lambda>(x)>,
#   'हर दिन एक कार्य जो निकटता से जुड़ा हुआ है'),
#  (<function __main__.<lambda>(x)>,
#   'भारत के संविधान के अनुच्छेद  में संविधान निर्माताओं ने यह व्यवस्था दी है  ? उच्चतम न्यायालय द्वारा घोषित विधि भारत के राज़्य क्षेत्र के भीतर सभी न्यायालयों पर आबद्धकर होगी  ?'),
#  (<function __main__.<lambda>(x)>, 'वह शहर एक द्वितीय स्वर्ग के समान हो गया।'),
#  (<function __main__.<lambda>(x)>, 'और अधिक दूर हो गया'),
#  (<function __main__.<lambda>(x)>,
#   'इस सामान्य उद्देश्य के साथ साथ  रेलवे विस्तार का कार्यक्रम भी  समय समय पर होने वाली विशेष विकासात्मक समस्याओं से निबटने के उद्देश्य से रहा है '),
#  (<function __main__.<lambda>(x)>,
#   'बिल्कुल अलग है और राष्ट्र क़रीबन-क़रीबन उसी दर से'),
#  (<function __main__.<lambda>(x)>,
#   'इससे आप मैजिस्ट्रेट को दिखा सकेंगे कि आफ का केस त्रक संगत है'),
#  (<function __main__.<lambda>(x)>,
#   'इनका पालन मुख़्य रूप से मांस के लिए ही किया जाता है '),
#  (<function __main__.<lambda>(x)>, 'वह बहुमुखी प्रतिभा संपन्न साहित्यकार थे।'),
#  (<function __main__.<lambda>(x)>,
#   'और जब वे उससे बरी हुए तो उन्हें अनुभव हुआ  ” मैं ठीक पहले जैसा आदमी नहीं रहा '),
#  (<function __main__.<lambda>(x)>,
#   ' में एबीसीएल द्वारा निर्मित मृत्युदाता Mrityudaata फिल्म से बच्चन ने अपने अभिनय में वापसी का प्रयास किया।'),
#  (<function __main__.<lambda>(x)>, 'फतेहपुर सीकरी का बुलन्द दरवाज़ा'),
#  (<function __main__.<lambda>(x)>,
#   'परिवहन व्यवस्था पर पड़ते भार को कम करने की द्Qष्टि से मुक़्त निर्यात को रोक दिया गया  और सन्  में निर्यात शुल्क लगाया गया जिसे सन्  में बढ़ा दिया गयालेकिन जूट निर्मित वस्तुओं का निर्यात समान रूप से बढ़ता ही गया जिससे इस क्षेत्र में भारत का एकाधिकार मान्य हुआ '),
#  (<function __main__.<lambda>(x)>,
#   'खुलने का समय   प्रातः से  साँयः शुक्रवार बन्द'),
#  (<function __main__.<lambda>(x)>,
#   'हज़रत हारिस \u200eफ़रमाते हैं कि मैं मस्जिद में प्रविष्ट हुआ तो देखा कि कुछ लोग कुछ \u200eसमस्याओं पर झगड़ा कर रहे हैं।'),
#  (<function __main__.<lambda>(x)>,
#   'स्पेन और तुर्की में कुछ लाइसेंस स्कूलों में इस्तेमाल के लिये।'),
#  (<function __main__.<lambda>(x)>,
#   'खिलडऋयिओं को एक टुर्नामेंट के लिए  ऋसे  ऋ  मिलते हैं '),
#  (<function __main__.<lambda>(x)>,
#   'इस तरह वह बालक अधिकाधिक विचारशील और आत्मविश्लेषी होता चला गया '),
#  (<function __main__.<lambda>(x)>, 'इसका अंग्रेजी में अनुवाद करना मुश्किल है'),
#  (<function __main__.<lambda>(x)>,
#   '  नयी हवाएं और नयी धाराएं दक्षिण में इस्लाम  अद्धेत  भक़्ति तथा राजपूत संस्कृति   ई- ईस्वी  हर्ष के बाद  वर्ष राजनैतिक फूट और बौद्धिक निष्क्रियता'),
#  (<function __main__.<lambda>(x)>,
#   'वे उत्तरी तट पर कृष्णा जिले में विजयवाड़ा और मोगलराजापुरम की पहाड़ियों में और दक्षिणी तट पर गुंटुर जिले में उदंवल्ली  पेनामागा और सीतारामपुरम की पहड़ियों में मिलते हैं '),
#  (<function __main__.<lambda>(x)>, 'इतिहास का एक अति महत्ती कार्य था'),
#  (<function __main__.<lambda>(x)>,
#   'हम देख चुके हैं कि बिज़्जल गलत तरीकों से सम्राट बना '),
#  (<function __main__.<lambda>(x)>, 'शोर से परेशान   ऐफ्  '),
#  (<function __main__.<lambda>(x)>,
#   'उन्होंने हमें तराशना शुरु किया हम तीनों बच्चों को'),
#  (<function __main__.<lambda>(x)>,
#   'ये  मै लेरि पेज और ब्राएन सर्जन के द्वरा स्तापिथ हुआ था ।'),
#  (<function __main__.<lambda>(x)>,
#   ' न्यायालय की कार्यवाही तथा निर्णय को दूसरे न्यायालय मे साक्ष्य के रूप मे प्रस्तुत किया जा सकेगा'),
#  (<function __main__.<lambda>(x)>, 'हमारी आशा के मुकाबले।'),
#  (<function __main__.<lambda>(x)>,
#   'बॉलीवुड हिन्दी चलचित्र उद्योग भी मुंबई में ही स्थित है।'),
#  (<function __main__.<lambda>(x)>, 'पहला था लघुकरण चीज़ को छोटा बनाना।'),
#  (<function __main__.<lambda>(x)>,
#   'गोलक नाथ के मामले में उच्चतम न्यायालय ने    के बहुमत से अपने पहले फैसलों को उलट दिया और यह फैसला सुनाया कि सम्मिलित मूल अधिकार अपरिवर्तनीय हैं  कि संविधान के अनुच्छेद  में केवल संशोधन करने की प्रक्रिया ही निर्धारित है और उसके द्वारा संविधान में संशोधन करने की कोई मूल शक़्ति अथवा साधारण विधायी शक़्ति से अलग कोई संविधायी शक़्ति संसद को प्रदान नहीं की गई है  कि संविधान संशोधन अधिनियम भी अनुच्छेद  के अर्थों में एक विधि है और इस प्रकार संसद अनुच्छेद  के अधीन पास किए गए किसी संविधान संशोधन अधिनियम के द्वारा भी मूल अधिकार समाप्त नहीं कर सकती या इनमें कोई कमी नहीं कर सकती '),
#  (<function __main__.<lambda>(x)>, 'बहुदेशी बजट के साथ'),
#  (<function __main__.<lambda>(x)>,
#   'व्यूरो ऑफ इंडस्ट्रियल कौस्ट्स एंड प्राइसेज  बीआईसीपी   ने सन्  में पूंजी निवेश पर कम से कम लाभ की सिफारिश की थी '),
#  (<function __main__.<lambda>(x)>,
#   'उसके लिए यह बड़ी यंत्रणा थी जिसे उसको सहन करना ही गुरू के पास शिक्षा के लिए ले जाया गया '),
#  (<function __main__.<lambda>(x)>,
#   'Lipikaar हिन्दी मे टाइप करने का सबसे प्रसिद्ध क्रम लिपिकार software कई पुरस्कार जीत चुका है अभी आज़माए'),
#  (<function __main__.<lambda>(x)>,
#   'झिल्ली के कसाव में यह परिवर्तन उससे निकलने वाली आवाज की आवृति को बदल सकता है और इस तरह अलग अलग प्रकार की मधुर आवाज निकाली जा सकती है '),
#  (<function __main__.<lambda>(x)>,
#   'दोनों जगहों पर सांस्कृतिक खोजबीन होती थी '),
#  (<function __main__.<lambda>(x)>, 'सरहाना व हर्षध्वनि'),
#  (<function __main__.<lambda>(x)>, 'तो यह एक तरह का वक्र था'),
#  (<function __main__.<lambda>(x)>,
#   'यह केवल इस बात पर निर्भर नही करता कि आप कितनी मात्रा में शक्कर का सेवन कर रहे है यह इस पर भी निर्भर करता है कि दिन भर में कितनी बार शक्कर का सेवन कर रहे है '),
#  (<function __main__.<lambda>(x)>,
#   'पहल रोमांच तो सरकारी इमारत में घुसने का होता है  जहां गंदे बदबूदार शौचालय और बंद पड़ी फाइलं का अंबार होता है '),
#  (<function __main__.<lambda>(x)>,
#   'कपोत स्तर उभारदार कुदु मॉटिफ से  विशेषकर हर दिशा के मध्य में अलंकृत होते हैं '),
#  (<function __main__.<lambda>(x)>, 'नई दुनिया'),
#  (<function __main__.<lambda>(x)>,
#   'श्री पुरुषोत्तम नागेश ओक ने कई बार हिन्दू धर्म की दूसरे धर्मों पर श्रेष्ठता प्रमाणित करने का प्रयास किया है।'),
#  (<function __main__.<lambda>(x)>,
#   'एक बल्लेबाज बिना आउट हुए भी मैदान को छोड़ सकता हैअगर उसे चोट लग जाए या वह घायल हो जाए तो वह अस्थायी रूप से जा सकता है उसे अगले बल्लेबाज के द्वारा प्रतिस्थापित कर दिया जाता हैइसे रिटायर्ड हर्ट retired hurt या रिटायर्ड बीमार retired illके रूप में दर्ज किया जाता हैरिटायर्ड बल्लेबाज नॉट आउट होता है और बाद में फ़िर से आ सकता हैएक अछूता बल्लेबाज रिटायर हो सकता है उसे रिटायर आउट retired outकहा जाता है; जिसका श्रेय किसी भी खिलाड़ी को नहीं जाता हैबल्लेबाज नो बॉलपर बोल्ड केच लेग बिफोर विकेट स्टंप्डया हिट विकेट आउट हो सकता है वो वाइड बॉलपर बोल्ड केच लेग बिफोर विकेट या बॉल को दो बार हिट करने पर आउट हो सकता है इनमें से कुछ प्रकार के आउट गेंदबाज के द्वारा बिना गेंद डाले ही हो सकते हैं नॉन-स्ट्राइकर बल्लेबाज भी रन आउट run out by the bowlerहो सकता है यदि वह गेंदबाज के द्वारा गेंद डालने से पहले क्रीज को छोड़ दे और एक बल्लेबाज क्षेत्ररक्षण बाधित करने पर या रिटायर आउट होने पर किसी भी समय आउट हो सकता हैसमय समाप्त बिना डिलीवरी के होने वाली बर्खास्तगी हैआउट होने के किसी भी तरीके में केवल एक ही बल्लेबाज एक गेंद पर आउट हो सकता है'),
#  (<function __main__.<lambda>(x)>,
#   'सर्वप्रथम सन्  में कवि शायर मुहम्मद इक़बाल ने द्विराष्ट्र सिद्धांत का ज़िक्र किया था ।'),
#  (<function __main__.<lambda>(x)>, 'यह जानिए कि आपके लिए प्राकृतिक क्या है'),
#  (<function __main__.<lambda>(x)>,
#   'एचईसी  अब अपने उत्पादों में वैविध्यकरण का कार्य हाथ में ले रहा है '),
#  (<function __main__.<lambda>(x)>,
#   'इनमें से प्रथम उद्देश्य यह मांग करता है कि सभी लड़के और लड़कियां Zबिना किसी वर्ग या जाति भेद के नि  शुल्क और अनिवार्य प्राथमिक शिक्षा व्यवस्था के अंतर्गत शिक्षित किये जायें तथा सभी कुशाग्र बुद्धि के बच्चों को बराबरी से उच्च शिक्षा का अवसर दिया जाये '),
#  (<function __main__.<lambda>(x)>, 'लेकिन जिन्हें आप समझ सकते है '),
#  (<function __main__.<lambda>(x)>,
#   'सरकार ने  के बजट में घोषणा की है कि हर वर्ष  मिलियन ऐक्शन टीम के  इलाकों में नौकरियाँ ढुँढने के ढंग सीखने में मदद देने के लिए खास निजी ट्रांस्पोर्ट की व्यवस्था करने की घोषणा भी की'),
#  (<function __main__.<lambda>(x)>,
#   'अब वीरप्पन अपने मशंर बंधक को रिहा कर एक बार फिर उसी जंगल में लपता हो गया है जहां से वह उभरा था  और चूंकि लगों की याददाश्त कमजोर होती है  हम जळ ही भारतीय प्रशासन व्यवस्था के उस कुरूप पहलू को भूल जाएंगे जो इस शर्मनाक प्रकरण की वजह से जाहिर हा था '),
#  (<function __main__.<lambda>(x)>,
#   'सौर ऊर्जा जो रोशनी व उष्मा दोनों रूपों में प्राप्त होती है का उपयोग कई प्रकार से हो सकता है।'),
#  (<function __main__.<lambda>(x)>,
#   'बॉक्स ऑफिस पर शोले जैसी फिल्मों की जबरदस्त सफलता के बाद बच्चन ने अब तक अपनी स्थिति को मजबूत कर लिया था और  से  तक उन्हें अनेक सर्वश्रेष्ठ कलाकार वाले फ़िल्मफ़ेयर पुरस्कार और अन्य पुरस्कार एवं ख्याति मिली।'),
#  (<function __main__.<lambda>(x)>,
#   'उसने कहा कि मैं अपना जीवन व्यर्थ कर रहा हूँ'),
#  (<function __main__.<lambda>(x)>, 'हंसी'),
#  (<function __main__.<lambda>(x)>, 'जो की वास्तविक हैकर थे '),
#  (<function __main__.<lambda>(x)>,
#   'इन कार्यविधियों की जानकारी प्राप्त हो जाने तक अपना काम प्रारंभ न करने को एक मूर्खता भरा कदम कहतेउन्होंने इसलिए पौधों तथा प्राणियों में आनुवंशिक परिवर्तन लाने हेतु परिवेश के करकों की सहायता लेने के प्रयास जारी रखना उचित समझा '),
#  (<function __main__.<lambda>(x)>,
#   ' शहर की अर्थव्यस्था हथकरघा वस्त्रों और कुछ धातु आधारित उद्योगों को शामिल करते हुए कई उद्योगों पर निर्भर करती है।'),
#  (<function __main__.<lambda>(x)>, ' प्रतिशत तक'),
#  (<function __main__.<lambda>(x)>,
#   'गरीबी की सही परिभाषा आखिर क्या है? गरीबी का अर्थ क्या है?'),
#  (<function __main__.<lambda>(x)>, 'कई औरतों को चाहे थोडी सी तकलीफ हो'),
#  (<function __main__.<lambda>(x)>,
#   'वित्त मंत्री जानते हैं कि वे खुद उस सरकार में काम कर रहे हैं जिसने आर्थिक सुधारों की प्रक्रिया रोक दी हैफिर भी वे करिश्मे और  फीसदी विकास दर की बात करते हैं '),
#  ...]
